# %% [markdown]
# # ***Поиск фотографий по текстовому описанию***
#
# Нам поручено разработать демонстрационную версию поиска изображений по запросу.
#
# Для демонстрационной версии нужно обучить модель, которая получит векторное представление изображения, векторное представление текста, а на выходе выдаст число от 0 до 1 — покажет, насколько текст и картинка подходят друг другу.

# %% [markdown]
# ## 1. Описание данных

# %% [markdown]
# В файле `train_dataset.csv` находится информация, необходимая для обучения: имя файла изображения, идентификатор описания и текст описания. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат `<имя файла изображения>#<порядковый номер описания>`.
#
# В папке `train_images` содержатся изображения для тренировки модели.
#
# В файле `CrowdAnnotations.tsv` — данные по соответствию изображения и описания, полученные с помощью краудсорсинга. Номера колонок и соответствующий тип данных:
#
# 1. Имя файла изображения.
# 2. Идентификатор описания.
# 3. Доля людей, подтвердивших, что описание соответствует изображению.
# 4. Количество человек, подтвердивших, что описание соответствует изображению.
# 5. Количество человек, подтвердивших, что описание не соответствует изображению.
#
# В файле `ExpertAnnotations.tsv` содержатся данные по соответствию изображения и описания, полученные в результате опроса экспертов. Номера колонок и соответствующий тип данных:
#
# 1. Имя файла изображения.
# 2. Идентификатор описания.
#
# 3, 4, 5 — оценки трёх экспертов.
#
# Эксперты ставят оценки по шкале от 1 до 4, где 1 — изображение и запрос совершенно не соответствуют друг другу, 2 — запрос содержит элементы описания изображения, но в целом запрос тексту не соответствует, 3 — запрос и текст соответствуют с точностью до некоторых деталей, 4 — запрос и текст соответствуют полностью.
#
# В файле `test_queries.csv` находится информация, необходимая для тестирования: идентификатор запроса, текст запроса и релевантное изображение. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат `<имя файла изображения>#<порядковый номер описания>`.
#
# В папке `test_images` содержатся изображения для тестирования модели.

# %% [markdown]
# ## 2. Подготовка среды

# %%
import numpy as np
import pandas as pd
import os
import re
import warnings
import random
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from sentence_transformers import SentenceTransformer
from math import sqrt
from PIL import Image
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Параметры и конфигурации для восроизводимости
RANDOM_STATE = 0
random.seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)
torch.manual_seed(RANDOM_STATE)
torch.cuda.manual_seed(RANDOM_STATE)
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":16:8"
torch.backends.cudnn.deterministic = True
torch.use_deterministic_algorithms(mode=True)
# Константы
TEST_SIZE = 0.3 # Относительная величина валидационных выборок
PATH = './dataset/to_upload/'   # Путь к данным
TRAIN_IMG_DIR = 'train_images/' # Папка с тренировочными изображениями
TEST_IMG_DIR = 'test_images/'   # Папка с тестовыми изображениями
n_samples = 3 # Величина случайных выборок для визуализации данных
warnings.simplefilter('ignore')
plt.rcParams["figure.dpi"] = 50
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Скачать файл по ссылке
if not os.path.isfile("./dataset.zip"):
    # !wget -q "https://code.s3.yandex.net/datasets/dsplus_integrated_project_4.zip" -O "./dataset.zip"
if not os.path.isdir(PATH):
    # !unzip -q -n "./dataset.zip" -d "./dataset"

# %%
os.listdir(PATH)
# Out:
# ['train_dataset.csv',
#  'test_queries.csv',
#  'ExpertAnnotations.tsv',
#  'test_images.csv',
#  '.DS_Store',
#  'test_images',
#  'train_images',
#  'CrowdAnnotations.tsv']

# %% [markdown]
# ## 3. Знакомство с данными

# %% [markdown]
# Загрузим и взглянем на тренировочные данные.

# %%
# Посмотрим на файл с описаниями
train_dataset_df = pd.read_csv(PATH + 'train_dataset.csv')
train_dataset_df.info()
train_dataset_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       5822 non-null   object
#  1   query_id    5822 non-null   object
#  2   query_text  5822 non-null   object
# dtypes: object(3)
# memory usage: 136.6+ KB
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
#
#                                           query_text
# 0  A young child is wearing blue goggles and sitt...
# 1  A young child is wearing blue goggles and sitt...
# 2  A young child is wearing blue goggles and sitt...
# 3  A young child is wearing blue goggles and sitt...
# 4  A young child is wearing blue goggles and sitt...

# %%
# Ознакомимся с тренировочными изображениями
imgs = train_dataset_df.sample(n=n_samples, random_state=RANDOM_STATE)
for i, img in enumerate(imgs['image']):
    fig = plt.figure(figsize=(7, 3.2))
    image = Image.open(PATH + TRAIN_IMG_DIR + img)
    plt.imshow(image)
    plt.title(f'\nОписание: {imgs["query_text"].iloc[i]}')
    plt.xlabel(f'Размер: {image.size}, {image.mode}')
    plt.ylabel(f'Файл: {img}')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %% [markdown]
# Ознакомимся с данными о краудсорсинговых оценках.

# %%
crowd_annotations_df = pd.read_csv(
    PATH + 'CrowdAnnotations.tsv',
    sep='\t',
    names= train_dataset_df.columns[:-1].tolist() + ['crowd_annotations_rate',
                                                     'crowd_annotations_1',
                                                     'crowd_annotations_0']
)
crowd_annotations_df.info()
crowd_annotations_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47830 entries, 0 to 47829
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   image                   47830 non-null  object
#  1   query_id                47830 non-null  object
#  2   crowd_annotations_rate  47830 non-null  float64
#  3   crowd_annotations_1     47830 non-null  int64
#  4   crowd_annotations_0     47830 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.8+ MB
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  1056338697_4f7d7ce270.jpg#2
# 1  1056338697_4f7d7ce270.jpg   114051287_dd85625a04.jpg#2
# 2  1056338697_4f7d7ce270.jpg  1427391496_ea512cbe7f.jpg#2
# 3  1056338697_4f7d7ce270.jpg  2073964624_52da3a0fc4.jpg#2
# 4  1056338697_4f7d7ce270.jpg  2083434441_a93bc6306b.jpg#2
#
#    crowd_annotations_rate  crowd_annotations_1  crowd_annotations_0
# 0                     1.0                    3                    0
# 1                     0.0                    0                    3
# 2                     0.0                    0                    3
# 3                     0.0                    0                    3
# 4                     0.0                    0                    3

# %% [markdown]
# Ознакомимся с данными об экспертных оценках.

# %%
expert_annotations_df = pd.read_csv(
    PATH + 'ExpertAnnotations.tsv',
    sep='\t',
    names= train_dataset_df.columns[:-1].tolist() + ['expert_1',
                                                     'expert_2',
                                                     'expert_3']
)
expert_annotations_df.info()
expert_annotations_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image     5822 non-null   object
#  1   query_id  5822 non-null   object
#  2   expert_1  5822 non-null   int64
#  3   expert_2  5822 non-null   int64
#  4   expert_3  5822 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 227.6+ KB
#                        image                     query_id  expert_1  expert_2  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2         1         1
# 1  1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2         1         1
# 2  1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2         1         1
# 3  1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2         1         2
# 4  1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2         1         1
#
#    expert_3
# 0         1
# 1         2
# 2         2
# 3         2
# 4         2

# %% [markdown]
# Взглянем на тестовые данные.

# %%
test_queries_df = pd.read_csv(
    PATH + 'test_queries.csv',
    sep='|', on_bad_lines='warn'
)
test_queries_df.info()
test_queries_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   query_id    500 non-null    object
#  2   query_text  500 non-null    object
#  3   image       500 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 15.8+ KB
#    Unnamed: 0                     query_id  \
# 0           0  1177994172_10d143cb8d.jpg#0
# 1           1  1177994172_10d143cb8d.jpg#1
# 2           2  1177994172_10d143cb8d.jpg#2
# 3           3  1177994172_10d143cb8d.jpg#3
# 4           4  1177994172_10d143cb8d.jpg#4
#
#                                           query_text  \
# 0  Two blonde boys , one in a camouflage shirt an...
# 1  Two boys are squirting water guns at each other .
# 2            Two boys spraying each other with water
# 3  Two children wearing jeans squirt water at eac...
# 4  Two young boys are squirting water at each oth...
#
#                        image
# 0  1177994172_10d143cb8d.jpg
# 1  1177994172_10d143cb8d.jpg
# 2  1177994172_10d143cb8d.jpg
# 3  1177994172_10d143cb8d.jpg
# 4  1177994172_10d143cb8d.jpg

# %%
# Ознакомимся с тестовыми изображениями
imgs = test_queries_df.sample(n=n_samples, random_state=RANDOM_STATE)
for i, img in enumerate(imgs['image']):
    fig = plt.figure(figsize=(7, 3.2))
    image = Image.open(PATH + TEST_IMG_DIR + img)
    plt.imshow(image)
    plt.title(f'\nОписание: {imgs["query_text"].iloc[i]}')
    plt.xlabel(f'Размер: {image.size}, {image.mode}')
    plt.ylabel(f'Файл: {img}')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %% [markdown]
# Итак, данные не содержат пропусков и в целом соответствуют описанию.

# %% [markdown]
# ## 4. Предобработка и анализ данных

# %% [markdown]
# Из тестовых данных удалим дублирующую индекс колонку `Unnamed: 0`.

# %%
test_queries_df = test_queries_df.drop(columns=['Unnamed: 0'])

# %% [markdown]
# Объединим таблицы с тренировочными данными.

# %%
train_df = train_dataset_df.merge(expert_annotations_df, how='left', on=['image', 'query_id'])  \
                           .merge(crowd_annotations_df, how='left', on=['image', 'query_id'])
train_df.info()
train_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   image                   5822 non-null   object
#  1   query_id                5822 non-null   object
#  2   query_text              5822 non-null   object
#  3   expert_1                5822 non-null   int64
#  4   expert_2                5822 non-null   int64
#  5   expert_3                5822 non-null   int64
#  6   crowd_annotations_rate  2329 non-null   float64
#  7   crowd_annotations_1     2329 non-null   float64
#  8   crowd_annotations_0     2329 non-null   float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 409.5+ KB
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
#
#                                           query_text  expert_1  expert_2  \
# 0  A young child is wearing blue goggles and sitt...         1         1
# 1  A young child is wearing blue goggles and sitt...         1         1
# 2  A young child is wearing blue goggles and sitt...         1         2
# 3  A young child is wearing blue goggles and sitt...         4         4
# 4  A young child is wearing blue goggles and sitt...         1         1
#
#    expert_3  crowd_annotations_rate  crowd_annotations_1  crowd_annotations_0
# 0         1                     0.0                  0.0                  3.0
# 1         1                     NaN                  NaN                  NaN
# 2         2                     0.0                  0.0                  3.0
# 3         4                     1.0                  3.0                  0.0
# 4         1                     NaN                  NaN                  NaN

# %% [markdown]
# Создадим единую оценку соответствия текстов и изображений на основе экспертных и краудсорсинговых оценок. Для этого возьмем среднюю оценку от экспертов и приведем ее к диапазону [0, 1]. Далее, сложим оценку экспертов с коэффициентом 0.6, а крауда (доля исполнителей, подтвердивших, что текст соответствует картинке) — с коэффициентом 0.4. В случае отсутствия оценок крауда применим только экспертные оценки с коэффициентом 1.

# %%
# Функция объединения оценок
def combine_rates(df):
  expert_rate = (df['expert_1'] + df['expert_2'] + df['expert_3'] - 3) / 9
  if pd.isna(df['crowd_annotations_rate']):
    return expert_rate
  else:
    return 0.6 * expert_rate + 0.4 * df['crowd_annotations_rate']

# %%
# Создание колонки с единой оценкой
train_df['target'] = train_df.apply(combine_rates, axis=1)
# Удаление исходных оценок из датафрейма
train_df = train_df.drop(columns=['expert_1',
                                  'expert_2',
                                  'expert_3',
                                  'crowd_annotations_rate',
                                  'crowd_annotations_1',
                                  'crowd_annotations_0'])
train_df.head()
# Out:
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
#
#                                           query_text    target
# 0  A young child is wearing blue goggles and sitt...  0.000000
# 1  A young child is wearing blue goggles and sitt...  0.000000
# 2  A young child is wearing blue goggles and sitt...  0.133333
# 3  A young child is wearing blue goggles and sitt...  1.000000
# 4  A young child is wearing blue goggles and sitt...  0.000000

# %% [markdown]
# Исследуем распределение полученных оценок.

# %%
print(train_df['target'].describe())

fig, ax = plt.subplots(figsize=(12, 4));
plt.hist(train_df['target'], bins=30);
plt.axvline(x=train_df['target'].median(), color='red', label='Медиана');
plt.axvline(x=train_df['target'].mean(), color='red', label='Среднее', linestyle='--');
plt.legend()
plt.title(f'Гистограмма оценки соответствия текста изображению')
plt.xlabel('Оценка')
plt.show();
# Out:
# count    5822.000000
# mean        0.183138
# std         0.247178
# min         0.000000
# 25%         0.000000
# 50%         0.111111
# 75%         0.222222
# max         1.000000
# Name: target, dtype: float64

# %% [markdown]
# Распределение оценок сильно смещено влево, средняя оценка - 0.18. В датасете преобладают примеры несоответствия либо слабого соответствия описаний и изображений.

# %% [markdown]
# ## 5. Проверка данных

# %% [markdown]
# В некоторых странах, где работают сервисы заказчика, действуют ограничения по обработке изображений: поисковым сервисам и сервисам, предоставляющим возможность поиска, запрещено без разрешения родителей или законных представителей предоставлять любую информацию, в том числе, но не исключительно тексты, изображения, видео и аудио, содержащие описание, изображение или запись голоса детей. Ребёнком считается любой человек, не достигший 16 лет. Все изображения, которые нарушают данный закон, нужно удалить из обучающей выборки.

# %% [markdown]
# Создадим функцию для удаления из датафрейма данных с упоминаниями детей.

# %%
def remove_restricted_data(data, verbose=True):
    df = data.copy()
    # Создаем список слов-исключений
    restricted_words = ['baby', 'babies', 'children', "child",
                        'boy', 'girl', 'teen', "kid", "teenager",
                        "minor", "adolescent", "youngster", "schoolboy", "schoolgirl", "youth"]
    for word in restricted_words[4:]:
        restricted_words.append(word + 's')

    # Создаем регулярное выражение: \b(word1|word2|word3)\b
    pattern = r'\b(' + '|'.join(map(re.escape, restricted_words)) + r')\b'

    # Проверяем совпадения
    mask = df['query_text'].str.contains(pattern, case=False, regex=True, na=False)
    if verbose:
        print('Количество строк с неприемлемым контентом:', sum(mask))

    approved_data = df[~mask].reset_index(drop=True)
    removed_data = df[mask]

    return approved_data, removed_data

# %% [markdown]
# Удалим юридически неприемлемый контент из тренировочных данных..

# %%
train_df, removed_data = remove_restricted_data(train_df)
# Out:
# Количество строк с неприемлемым контентом: 1548

# %%
print(f'Выборка из {n_samples} удаленных строк:')
for text in removed_data.sample(n=n_samples, random_state=RANDOM_STATE)['query_text']:
    print(text)
# Out:
# Выборка из 3 удаленных строк:
# A little girl wearing sunglasses puts her feet into the kitchen sink .
# Two woman in colorful costumes look at a little girl wearing a brown vest .
# A group of people with their backs to the camera and a little girl facing a lady .

# %% [markdown]
# ## 6. Векторизация признаков

# %% [markdown]
# Создадим модель для эмбеддинга текстов. Для этого используем популярную трансформерную модель из хаба Huggingface для задачи извлечения признаков из текстов (BAAI/bge-large-en-v1.5). Напишем функцию для создания эмбеддингов текстов.

# %%
MODEL_NAME = "BAAI/bge-large-en-v1.5"

text_embedder = SentenceTransformer(MODEL_NAME, device=device)
text_embedder.max_seq_length = 512

def embed_texts(text_embedder, data, batch_size=128):
    """Batch-process texts with automatic normalization"""
    df = data.copy()
    embeds = text_embedder.encode(
        df["query_text"].tolist(),
        batch_size=batch_size,
        convert_to_tensor=True,
        device=device
    ).cpu()

    df["text_embeds"] = list(embeds)
    return df
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/779 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %% [markdown]
# Создадим эмбеддинги текстов тренировочной выборки.

# %%
train_df = embed_texts(text_embedder, train_df)
print('Размерность эмбеддинга текстового описания:', train_df["text_embeds"][0].size())
# Out:
# Размерность эмбеддинга текстового описания: torch.Size([1024])

# %% [markdown]
# Далее, создадим модель для создания эмбеддингов изображений. Для этого будем использовать предобученную модель ResNet50.

# %%
resnet = models.resnet50(weights='DEFAULT')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 167MB/s]

# %%
# "Заморозим" параметры модели
for param in resnet.parameters():
    param.requires_grad_(False)

# %%
# Проверяем количество обучаемых параметров
trainable_params = sum(p.numel() for p in resnet.parameters() if p.requires_grad)
total_params = sum(p.numel() for p in resnet.parameters())
print(f"Обучаемые параметры: {trainable_params} ({trainable_params/total_params:.2%} от общего числа {total_params})")
# Out:
# Обучаемые параметры: 0 (0.00% от общего числа 25557032)

# %%
print(list(resnet.children()))
# Out:
# [Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False), BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), ReLU(inplace=True), MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False), Sequential(
#   (0): Bottleneck(
#     (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (downsample): Sequential(
#       (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): Bottleneck(
#     (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (2): Bottleneck(
#     (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
# ), Sequential(
#   (0): Bottleneck(
#     (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): Bottleneck(
#     (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (2): Bottleneck(
#     (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (3): Bottleneck(
#     (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
# ), Sequential(
#   (0): Bottleneck(
#     (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (downsample): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): Bottleneck(
#     (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (2): Bottleneck(
#     (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (3): Bottleneck(
#     (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (4): Bottleneck(
#     (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (5): Bottleneck(
#     (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
# ), Sequential(
#   (0): Bottleneck(
#     (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (downsample): Sequential(
#       (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): Bottleneck(
#     (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
#   (2): Bottleneck(
#     (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#   )
# ), AdaptiveAvgPool2d(output_size=(1, 1)), Linear(in_features=2048, out_features=1000, bias=True)]

# %% [markdown]
# Для создания эмбеддингов будем использовать все слои модели кроме последнего.

# %%
modules = list(resnet.children())[:-1]
resnet = nn.Sequential(*modules).to(device)

# Определяем модель для создания эмбеддингов изображений
img_embedder = resnet.eval()

# %% [markdown]
# Подготовим класс для нормализации изображений.

# %%
norm = transforms.Normalize(
    mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    norm,
])

# %% [markdown]
# Определим функцию для создания эмбеддингов изображений.

# %%
def embed_imgs(img_embedder, data, img_path=TRAIN_IMG_DIR):
    df = data.copy()
    img_embeds = []

    for img_file in df['image']:
      img = Image.open(PATH + img_path + img_file).convert('RGB')
      image_tensor = preprocess(img)
      output_tensor = resnet(image_tensor.resize_(1, 3, 224, 224).to(device)).flatten()
      img_embeds.append(output_tensor.cpu())

    df['img_embeds'] = img_embeds
    return df

# %% [markdown]
# Создадим эмбеддинги тренировочных изображений.

# %%
train_df = embed_imgs(img_embedder, train_df)
print('Размерность эмбеддинга изображения:', train_df['img_embeds'][0].size())
# Out:
# Размерность эмбеддинга изображения: torch.Size([2048])

# %% [markdown]
# ## 7. Обучение модели предсказания соответствия

# %% [markdown]
# Будем работать с фрэймворком `pytorch`. Создадим и обучим модели линейной регрессии и полносвязных нейронных сетей. По сути, мы имеем дело с задачей регрессии, поэтому для оценки моделей будет разумно использовать метрику R2. В дополнение к этому, будем отслеживать метрику MAE. Для более адекватного сравнения моделей перед подсчетом метрик применим к предсказаниям линейной регрессии функцию сигмоиды (та же функция будет применена к выходному нейрону нейронной сети).

# %% [markdown]
# Зададим гипараметры обучения моделей.

# %%
batch_size = 16
num_epochs = 50
patience = 5 # Сколько эпох ждать улучшения метрики до прерывания обучения модели
input_size = train_df['img_embeds'][0].shape[0] + train_df['text_embeds'][0].shape[0]
n_splits = 3 # Количество шагов кроссвалидации

# %% [markdown]
# Подготовим тренировочную выборку для обучения моделей.

# %%
# Создаем тензоры статистик для нормализации данных
mean_txt = torch.stack(train_df['text_embeds'].tolist()).mean(dim=0)
std_txt = torch.stack(train_df['text_embeds'].tolist()).std(dim=0)
mean_img = torch.stack(train_df['img_embeds'].tolist()).mean(dim=0)
std_img = torch.stack(train_df['img_embeds'].tolist()).std(dim=0)

# Создаем transform для нормализации данных
class Normalize:
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, x):
        return (x - self.mean) / self.std

# %%
# создадим класс, преобразующий наш DataFrame в Dataset
class Dataframe_to_Dataset(Dataset):
    def __init__(self, df, transform_txt=None,transform_img=None, train=True):
        self.df = df
        self.transform_txt = transform_txt
        self.transform_img = transform_img
        self.train = train
    def __len__(self):
        return len(self.df)
    def __getitem__(self, idx):
        row = self.df.iloc[idx, :]
        if self.transform_txt and self.transform_img:
            features = torch.cat((self.transform_txt(row['text_embeds']), self.transform_img(row['img_embeds'])))
        else:
            features = torch.cat((row['text_embeds'], row['img_embeds']))
        if self.train:
            target = row['target']
            return features.type('torch.FloatTensor'), torch.tensor(target).type('torch.FloatTensor')
        else:
            return features.type('torch.FloatTensor')

# %% [markdown]
# Определим функцию, принимающую на вход исходный датафрейм, индексы тренировочной и валидационной выборок и возвращающую загрузчики (Dataloader) тренировочной и валидационной выборок.

# %%
def load_data(dataframe, train_indices, val_indices=None, train=True):
    df = dataframe.copy()
    if train:
        columns = ['text_embeds', 'img_embeds', 'target']
    else:
        columns = ['text_embeds', 'img_embeds']
    df_train = df.loc[train_indices]
    if val_indices is not None:
        df_val = df.loc[val_indices]
    else:
        df_val = None
    # инициализируем тренировочный и валидационный датасеты, нормализуем признаки
    train_dataset = Dataframe_to_Dataset(
        df_train[columns],
        transform_txt=lambda x: Normalize(mean_txt, std_txt)(x),
        transform_img=lambda x: Normalize(mean_img, std_img)(x),
        train=train
        )
    if df_val is not None:
        val_dataset = Dataframe_to_Dataset(
            df_val[columns],
            transform_txt=lambda x: Normalize(mean_txt, std_txt)(x),
            transform_img=lambda x: Normalize(mean_img, std_img)(x),
            train=train
            )
    else:
        val_dataset = None
    # обернем данные в DataLoader
    train_loader = DataLoader(dataset=train_dataset,
                             batch_size=batch_size,
                             drop_last=True,
                             shuffle=train)
    if val_dataset is not None:
        val_loader = DataLoader(dataset=val_dataset,
                                 batch_size=batch_size,
                                 drop_last=True,
                                 shuffle=False)
    else:
        val_loader = None

    return train_loader, val_loader

# %% [markdown]
# Создадим класс для прерывания обучения по результатам мониторинга метрики.

# %%
class EarlyStopping:
    def __init__(self,
                 patience=5,
                 mode='min',
                 delta=0.001,
                 restore_best_weights=True):
        """
        Args:
            patience (int): Сколько эпох ждать после последнего улучшения метрики
            mode (str): 'min' для метрик "меньше - лучше", 'max' в противном случае
            delta (float): минимальное изменение, считающееся улучшением
            restore_best_weights (bool): восстанавливать ли модель к лучшему состоянию
        """
        self.patience = patience
        self.mode = mode
        self.delta = delta
        self.restore_best = restore_best_weights
        self.counter = 0
        self.best_score = None
        self.best_score_2 = None
        self.early_stop = False
        self.best_model_state = None

    def __call__(self, current_score, current_score_2, model):
        if self.best_score is None:
            # Инициализация при первом вызове
            self.best_score = current_score
            self.best_score_2 = current_score_2
            self.best_model_state = model.state_dict()
        else:
            if self.mode == 'min':
                improved = current_score < (self.best_score - self.delta)
            elif self.mode == 'max':
                improved = current_score > (self.best_score + self.delta)
            else:
                raise ValueError("Invalid early stopping mode")

            if improved:
                self.best_score = current_score
                self.best_score_2 = current_score_2
                self.counter = 0
                self.best_model_state = model.state_dict()
            else:
                self.counter += 1
                print(f'EarlyStopping counter: {self.counter}/{self.patience}')

            if self.counter >= self.patience:
                self.early_stop = True
                if self.restore_best:
                    print('Restoring best model weights')
                    model.load_state_dict(self.best_model_state)

        return self.early_stop

# %% [markdown]
# Зададим архитектуру моделей линейной регрессии.

# %%
class LinearRegression(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.linear = nn.Linear(input_size, 1)

        # Инициализация весов
        nn.init.kaiming_normal_(self.linear.weight)
        nn.init.constant_(self.linear.bias, 0)

    def forward(self, x):
        return self.linear(x)

# %% [markdown]
# Зададим архитектуру моделей нейронной сети.

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_fraction):
        super(NeuralNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.dropout1 = nn.Dropout(p=dropout_fraction)
        self.bn1 = nn.BatchNorm1d(hidden_size)
        self.gelu1 = nn.GELU()
        self.fc2 = nn.Linear(hidden_size,  hidden_size)
        self.dropout2 = nn.Dropout(p=dropout_fraction)
        self.bn2 = nn.BatchNorm1d(hidden_size)
        self.gelu2 = nn.GELU()
        self.fc3 = nn.Linear(hidden_size,  1)
        self.sigmoid = nn.Sigmoid()

        nn.init.kaiming_normal_(self.fc1.weight)
        nn.init.kaiming_normal_(self.fc2.weight)
        nn.init.xavier_normal_(self.fc3.weight)

    def forward(self, x):
        out = self.fc1(x)
        out = self.bn1(out)
        out = self.gelu1(out)
        out = self.dropout1(out)
        out = self.fc2(out)
        out = self.bn2(out)
        out = self.gelu2(out)
        out = self.dropout2(out)
        out = self.fc3(out)
        out = self.sigmoid(out)
        return out

# %% [markdown]
# Обучим модели на тренировочной выборке с кроссвалидацией и подбором гиперпараметров в циклах.

# %%
# Определим функцию сигмоиды для массивов numpy
def np_sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
# создадим функцию для инициализации и обучения модели
def init_train_model(architecture='nn', # 'nn' - для нейронной сети, 'lr' - для регрессии
                hidden_size=None,
                dropout_fraction=None,
                learning_rate=0.0001,
                train_loader=None,
                val_loader=None,
                num_epochs=num_epochs,
                verbose=True):
    # Инициализация модели
    if architecture=='nn':
        model = NeuralNet(input_size, hidden_size, dropout_fraction)
        model = torch.nn.DataParallel(model)
        model = model.to(device)
        criterion = nn.BCELoss()
        optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

    else:
        model = LinearRegression(input_size)
        model = torch.nn.DataParallel(model)
        model = model.to(device)
        criterion = nn.MSELoss()
        optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

    # Создание прерывания
    early_stopper = EarlyStopping(
    patience=patience,
    mode='max' if architecture=='nn' else 'min',
    delta=0.005,
    restore_best_weights=True
)
    # Цикл обучения
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        train_mae = 0.0
        train_r2 = 0.0
        for i, (_data, target) in enumerate(train_loader):

            # Прямой проход
            target = target.unsqueeze(-1).to(device)
            _data = _data.to(device)
            outputs = model(_data)
            loss = criterion(outputs, target)

            # Обратный проход
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * _data.size(0)
            train_mae += mean_absolute_error(target.detach().cpu(),
                                             outputs.detach().cpu()) * _data.size(0)
            if architecture=='nn':
                train_r2 += r2_score(target.detach().cpu(),
                                     outputs.detach().cpu()) * _data.size(0)
            else:
                train_r2 += r2_score(target.detach().cpu(),
                                     nn.Sigmoid()(outputs.detach().cpu()).flatten()) * _data.size(0)

        # Валидация
        model.eval()
        val_loss = 0
        all_preds = []
        all_targets = []

        # Если не предоставлена валидационная выборка, валидация будет производиться на всей тренировочной выборке
        if val_loader is None:
            val_loader = train_loader

        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.unsqueeze(-1).to(device)
                outputs = model(inputs)
                val_loss += criterion(outputs, targets).item() * inputs.size(0)

                all_preds.extend(outputs.cpu().numpy())
                all_targets.extend(targets.cpu().numpy())

        # Считаем метрики и средние функции потерь
        train_loss /= len(train_loader.dataset)
        train_mae /= len(train_loader.dataset)
        train_r2 /= len(train_loader.dataset)
        val_loss /= len(val_loader.dataset)
        if architecture=='nn':
            val_r2 = r2_score(np.array(all_targets), np.array(all_preds))
            val_mae = mean_absolute_error(np.array(all_targets), np.array(all_preds))
        else:
            val_r2 = r2_score(np.array(all_targets), np_sigmoid(np.array(all_preds)))
            val_mae = mean_absolute_error(np.array(all_targets), np_sigmoid(np.array(all_preds)))
        if verbose:
                print ('Эпоха [{}/{}], train-loss: {:.5f}, train-r2: {:.5f}, val-loss: {:.5f}, val-r2: {:.5f}, val-mae: {:.5f}'
                       .format(epoch+1, num_epochs, train_loss, train_r2, val_loss, val_r2, val_mae))

        # Проверяем условие прерывания обучения
        monitored_metric = val_r2
        monitored_metric_2 = val_mae
        if early_stopper(monitored_metric, monitored_metric_2, model):
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

    # Финальная проверка, чтобы удостовериться, что вернется модель с лучшими весами
    if early_stopper.restore_best and not early_stopper.early_stop:
        model.load_state_dict(early_stopper.best_model_state)

    return model, early_stopper.best_score, early_stopper.best_score_2

# %% [markdown]
# Зададим варианты перебора гиперпараметров моделей для кроссвалидации.

# %%
# Гиперпараметры нейронных сетей
nn_train_params = {'hidden_size': [512, input_size],
                   'dropout_fraction': [0., 0.2],
                   'learning_rate': [0.001, 0.0001]}
# Гиперпараметры линейной регрессии
lr_train_params = {'learning_rate': [0.01, 0.001, 0.0001]}

# %% [markdown]
# Подберем и обучим модель линейной регрессии.

# %%
best_lr_model = None       # Лучшая модель на кроссвалидации
best_lr_metric = -10000      # Лучшая метрика MSE на кроссвалидации
best_lr_metric_2 = 10000    # Лучшая метрика MAE на кроссвалидации
best_lr_params = {}        # Лучшие гиперпараметры на кроссвалидации

# Цикл перебора гиперпараметров с кроссвалидацией

for learning_rate in lr_train_params['learning_rate']:
    print(f'Testing parameter: learning_rate={learning_rate}')

    gss = GroupShuffleSplit(n_splits=n_splits, test_size=TEST_SIZE, random_state=RANDOM_STATE)
    best_metrics = []
    best_metrics_2 = []
    # Цикл кроссвалидации
    for train_indices, val_indices in gss.split(train_df, groups=train_df['image']):
        train_loader, val_loader = load_data(train_df, train_indices, val_indices)
        _, best_score, best_score_2 = init_train_model( architecture='lr',
                                                        hidden_size=None,
                                                        dropout_fraction=None,
                                                        learning_rate=learning_rate,
                                                        train_loader=train_loader,
                                                        val_loader=val_loader)
        best_metrics.append(best_score)
        best_metrics_2.append(best_score_2)
    # Сохраняем лучшие средние значения метрик на кроссвалидации и соответствующие им гиперпараметры
    if sum(best_metrics)/n_splits > best_lr_metric:
        best_lr_metric = sum(best_metrics)/n_splits
        best_lr_metric_2 = sum(best_metrics_2)/n_splits
        best_lr_params['learning_rate'] = learning_rate

# Обучаем модель с лучшими гиперпараметрами
train_loader, _ = load_data(train_df, train_df.index)
best_lr_model, best_lr_score, best_lr_score_2 = init_train_model( architecture='lr',
                                                            train_loader=train_loader,
                                                            val_loader=None,
                                                            **best_lr_params)
# Out:
# Testing parameter: learning_rate=0.01
# Эпоха [1/50], train-loss: 17.66693, train-r2: -6.33757, val-loss: 9.77303, val-r2: -3.03527, val-mae: 0.39552
# Эпоха [2/50], train-loss: 12.35678, train-r2: -6.42180, val-loss: 14.61780, val-r2: -3.45660, val-mae: 0.42205
# Эпоха [3/50], train-loss: 20.72456, train-r2: -6.95965, val-loss: 14.89154, val-r2: -3.67956, val-mae: 0.42863
# Эпоха [4/50], train-loss: 19.78992, train-r2: -6.35953, val-loss: 11.37721, val-r2: -3.88198, val-mae: 0.44854
# Эпоха [5/50], train-loss: 11.85288, train-r2: -6.30620, val-loss: 8.63042, val-r2: -3.79317, val-mae: 0.44816
# EarlyStopping counter: 1/5
# Эпоха [6/50], train-loss: 19.75740, train-r2: -6.64562, val-loss: 25.28184, val-r2: -4.53569, val-mae: 0.47361
# Эпоха [7/50], train-loss: 29.82702, train-r2: -8.76453, val-loss: 18.66361, val-r2: -3.84904, val-mae: 0.43251
# EarlyStopping counter: 1/5
# Эпоха [8/50], train-loss: 17.58548, train-r2: -5.72851, val-loss: 11.64308, val-r2: -4.04874, val-mae: 0.45478
# EarlyStopping counter: 2/5
# Эпоха [9/50], train-loss: 14.65712, train-r2: -5.94964, val-loss: 7.97855, val-r2: -3.50268, val-mae: 0.42871
# EarlyStopping counter: 3/5
# Эпоха [10/50], train-loss: 7.51408, train-r2: -5.61875, val-loss: 5.80770, val-r2: -3.09483, val-mae: 0.40919
# EarlyStopping counter: 4/5
# Эпоха [11/50], train-loss: 9.45585, train-r2: -6.26719, val-loss: 10.78218, val-r2: -3.52483, val-mae: 0.42407
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 11
# Эпоха [1/50], train-loss: 17.17928, train-r2: -9.00519, val-loss: 8.83531, val-r2: -2.88397, val-mae: 0.43200
# Эпоха [2/50], train-loss: 17.81935, train-r2: -7.29688, val-loss: 9.43119, val-r2: -2.77020, val-mae: 0.42447
# EarlyStopping counter: 1/5
# Эпоха [3/50], train-loss: 12.45527, train-r2: -7.53203, val-loss: 10.36435, val-r2: -2.88788, val-mae: 0.42993
# EarlyStopping counter: 2/5
# Эпоха [4/50], train-loss: 18.90087, train-r2: -7.88779, val-loss: 13.36804, val-r2: -2.88795, val-mae: 0.42735
# EarlyStopping counter: 3/5
# Эпоха [5/50], train-loss: 17.03964, train-r2: -8.04624, val-loss: 11.39751, val-r2: -3.15717, val-mae: 0.45082
# Эпоха [6/50], train-loss: 20.29568, train-r2: -7.24408, val-loss: 15.65497, val-r2: -2.90327, val-mae: 0.42623
# EarlyStopping counter: 1/5
# Эпоха [7/50], train-loss: 28.27453, train-r2: -7.52080, val-loss: 18.21832, val-r2: -3.13859, val-mae: 0.43996
# EarlyStopping counter: 2/5
# Эпоха [8/50], train-loss: 17.69679, train-r2: -7.72347, val-loss: 10.84127, val-r2: -3.01365, val-mae: 0.43944
# EarlyStopping counter: 3/5
# Эпоха [9/50], train-loss: 10.57080, train-r2: -7.02157, val-loss: 7.58132, val-r2: -2.28478, val-mae: 0.39301
# EarlyStopping counter: 4/5
# Эпоха [10/50], train-loss: 9.28767, train-r2: -6.43176, val-loss: 7.98703, val-r2: -2.99078, val-mae: 0.44465
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 10
# Эпоха [1/50], train-loss: 17.99493, train-r2: -6.83008, val-loss: 11.22753, val-r2: -3.03210, val-mae: 0.43689
# Эпоха [2/50], train-loss: 17.71005, train-r2: -8.35776, val-loss: 8.13786, val-r2: -3.00559, val-mae: 0.44159
# EarlyStopping counter: 1/5
# Эпоха [3/50], train-loss: 11.11420, train-r2: -7.00752, val-loss: 7.65915, val-r2: -2.77844, val-mae: 0.42264
# EarlyStopping counter: 2/5
# Эпоха [4/50], train-loss: 17.18464, train-r2: -8.00672, val-loss: 17.99955, val-r2: -3.19486, val-mae: 0.43999
# Эпоха [5/50], train-loss: 20.06730, train-r2: -7.17022, val-loss: 11.97226, val-r2: -3.17028, val-mae: 0.44719
# EarlyStopping counter: 1/5
# Эпоха [6/50], train-loss: 14.19073, train-r2: -6.91682, val-loss: 8.61930, val-r2: -3.10523, val-mae: 0.44467
# EarlyStopping counter: 2/5
# Эпоха [7/50], train-loss: 17.72083, train-r2: -7.38145, val-loss: 13.81964, val-r2: -3.18887, val-mae: 0.44331
# EarlyStopping counter: 3/5
# Эпоха [8/50], train-loss: 19.82686, train-r2: -7.13216, val-loss: 14.25546, val-r2: -3.15997, val-mae: 0.44106
# EarlyStopping counter: 4/5
# Эпоха [9/50], train-loss: 21.83914, train-r2: -7.24591, val-loss: 11.49212, val-r2: -3.03668, val-mae: 0.43480
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 9
# Testing parameter: learning_rate=0.001
# Эпоха [1/50], train-loss: 0.72073, train-r2: -3.62053, val-loss: 0.82173, val-r2: -1.87985, val-mae: 0.37289
# Эпоха [2/50], train-loss: 0.21797, train-r2: -3.77513, val-loss: 0.79741, val-r2: -1.79251, val-mae: 0.36706
# EarlyStopping counter: 1/5
# Эпоха [3/50], train-loss: 0.17996, train-r2: -3.56630, val-loss: 0.76282, val-r2: -1.87197, val-mae: 0.37520
# EarlyStopping counter: 2/5
# Эпоха [4/50], train-loss: 0.18578, train-r2: -3.66552, val-loss: 0.87641, val-r2: -1.89247, val-mae: 0.37644
# Эпоха [5/50], train-loss: 0.28828, train-r2: -3.28332, val-loss: 0.79556, val-r2: -1.80842, val-mae: 0.37066
# EarlyStopping counter: 1/5
# Эпоха [6/50], train-loss: 0.19226, train-r2: -3.16348, val-loss: 0.75333, val-r2: -1.83866, val-mae: 0.37229
# EarlyStopping counter: 2/5
# Эпоха [7/50], train-loss: 0.19600, train-r2: -3.59619, val-loss: 0.72624, val-r2: -1.81924, val-mae: 0.37379
# EarlyStopping counter: 3/5
# Эпоха [8/50], train-loss: 0.22576, train-r2: -3.66327, val-loss: 0.77596, val-r2: -1.93211, val-mae: 0.37861
# Эпоха [9/50], train-loss: 0.21151, train-r2: -3.78629, val-loss: 0.75278, val-r2: -1.81194, val-mae: 0.37191
# EarlyStopping counter: 1/5
# Эпоха [10/50], train-loss: 0.24766, train-r2: -3.56867, val-loss: 0.88339, val-r2: -1.87668, val-mae: 0.37377
# EarlyStopping counter: 2/5
# Эпоха [11/50], train-loss: 0.23664, train-r2: -3.82377, val-loss: 0.67921, val-r2: -1.83528, val-mae: 0.37349
# EarlyStopping counter: 3/5
# Эпоха [12/50], train-loss: 0.21135, train-r2: -3.57275, val-loss: 0.84555, val-r2: -1.89181, val-mae: 0.37578
# EarlyStopping counter: 4/5
# Эпоха [13/50], train-loss: 0.22734, train-r2: -3.34697, val-loss: 0.72833, val-r2: -1.99079, val-mae: 0.38232
# Эпоха [14/50], train-loss: 0.24350, train-r2: -3.88278, val-loss: 0.78872, val-r2: -1.81117, val-mae: 0.37087
# EarlyStopping counter: 1/5
# Эпоха [15/50], train-loss: 0.25476, train-r2: -3.56042, val-loss: 0.75535, val-r2: -1.99265, val-mae: 0.38210
# EarlyStopping counter: 2/5
# Эпоха [16/50], train-loss: 0.26379, train-r2: -3.78891, val-loss: 0.76720, val-r2: -1.83994, val-mae: 0.37405
# EarlyStopping counter: 3/5
# Эпоха [17/50], train-loss: 0.24789, train-r2: -3.28018, val-loss: 0.73356, val-r2: -1.86256, val-mae: 0.37517
# EarlyStopping counter: 4/5
# Эпоха [18/50], train-loss: 0.20864, train-r2: -3.50313, val-loss: 0.72149, val-r2: -1.81608, val-mae: 0.37304
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 18
# Эпоха [1/50], train-loss: 0.77890, train-r2: -4.52338, val-loss: 0.73163, val-r2: -1.33788, val-mae: 0.36539
# Эпоха [2/50], train-loss: 0.20104, train-r2: -4.73515, val-loss: 0.68320, val-r2: -1.29168, val-mae: 0.36169
# EarlyStopping counter: 1/5
# Эпоха [3/50], train-loss: 0.15474, train-r2: -4.15084, val-loss: 0.75400, val-r2: -1.36148, val-mae: 0.36725
# Эпоха [4/50], train-loss: 0.19538, train-r2: -4.17824, val-loss: 0.67366, val-r2: -1.34656, val-mae: 0.36834
# EarlyStopping counter: 1/5
# Эпоха [5/50], train-loss: 0.20532, train-r2: -4.37993, val-loss: 0.72501, val-r2: -1.39732, val-mae: 0.36978
# Эпоха [6/50], train-loss: 0.20796, train-r2: -3.82461, val-loss: 0.69761, val-r2: -1.30072, val-mae: 0.36202
# EarlyStopping counter: 1/5
# Эпоха [7/50], train-loss: 0.24014, train-r2: -4.90491, val-loss: 0.76074, val-r2: -1.42486, val-mae: 0.36996
# Эпоха [8/50], train-loss: 0.24834, train-r2: -4.70039, val-loss: 0.70593, val-r2: -1.38827, val-mae: 0.36831
# EarlyStopping counter: 1/5
# Эпоха [9/50], train-loss: 0.23213, train-r2: -4.53678, val-loss: 0.71728, val-r2: -1.40399, val-mae: 0.37000
# EarlyStopping counter: 2/5
# Эпоха [10/50], train-loss: 0.23784, train-r2: -3.96383, val-loss: 0.75315, val-r2: -1.35658, val-mae: 0.36300
# EarlyStopping counter: 3/5
# Эпоха [11/50], train-loss: 0.28624, train-r2: -4.36063, val-loss: 0.74563, val-r2: -1.40479, val-mae: 0.36836
# EarlyStopping counter: 4/5
# Эпоха [12/50], train-loss: 0.20946, train-r2: -4.48879, val-loss: 0.69815, val-r2: -1.37168, val-mae: 0.36934
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 12
# Эпоха [1/50], train-loss: 0.69879, train-r2: -4.25780, val-loss: 0.77732, val-r2: -1.50662, val-mae: 0.37655
# Эпоха [2/50], train-loss: 0.20778, train-r2: -3.76042, val-loss: 0.66965, val-r2: -1.47293, val-mae: 0.37631
# EarlyStopping counter: 1/5
# Эпоха [3/50], train-loss: 0.16474, train-r2: -4.26931, val-loss: 0.66714, val-r2: -1.48289, val-mae: 0.37709
# EarlyStopping counter: 2/5
# Эпоха [4/50], train-loss: 0.18180, train-r2: -3.70200, val-loss: 0.71429, val-r2: -1.45172, val-mae: 0.37391
# EarlyStopping counter: 3/5
# Эпоха [5/50], train-loss: 0.22759, train-r2: -3.84005, val-loss: 0.71905, val-r2: -1.52202, val-mae: 0.38049
# Эпоха [6/50], train-loss: 0.25619, train-r2: -4.59850, val-loss: 0.69566, val-r2: -1.46564, val-mae: 0.37654
# EarlyStopping counter: 1/5
# Эпоха [7/50], train-loss: 0.20799, train-r2: -3.27095, val-loss: 0.61199, val-r2: -1.47479, val-mae: 0.37854
# EarlyStopping counter: 2/5
# Эпоха [8/50], train-loss: 0.18324, train-r2: -3.59774, val-loss: 0.65035, val-r2: -1.43064, val-mae: 0.37518
# EarlyStopping counter: 3/5
# Эпоха [9/50], train-loss: 0.21928, train-r2: -4.15209, val-loss: 0.73498, val-r2: -1.50157, val-mae: 0.37843
# EarlyStopping counter: 4/5
# Эпоха [10/50], train-loss: 0.20653, train-r2: -4.11143, val-loss: 0.75682, val-r2: -1.45517, val-mae: 0.37260
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 10
# Testing parameter: learning_rate=0.0001
# Эпоха [1/50], train-loss: 1.36012, train-r2: -3.52120, val-loss: 1.45379, val-r2: -2.55533, val-mae: 0.40810
# Эпоха [2/50], train-loss: 0.78199, train-r2: -3.65179, val-loss: 1.20779, val-r2: -2.39964, val-mae: 0.40284
# EarlyStopping counter: 1/5
# Эпоха [3/50], train-loss: 0.55554, train-r2: -3.30473, val-loss: 1.11884, val-r2: -2.35652, val-mae: 0.40185
# EarlyStopping counter: 2/5
# Эпоха [4/50], train-loss: 0.41825, train-r2: -3.56104, val-loss: 1.03843, val-r2: -2.27860, val-mae: 0.39840
# EarlyStopping counter: 3/5
# Эпоха [5/50], train-loss: 0.32938, train-r2: -3.07097, val-loss: 0.99151, val-r2: -2.25329, val-mae: 0.39778
# EarlyStopping counter: 4/5
# Эпоха [6/50], train-loss: 0.26490, train-r2: -3.24578, val-loss: 0.94236, val-r2: -2.19719, val-mae: 0.39496
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 6
# Эпоха [1/50], train-loss: 1.48286, train-r2: -5.09364, val-loss: 1.05482, val-r2: -1.73442, val-mae: 0.38729
# Эпоха [2/50], train-loss: 0.78367, train-r2: -4.25296, val-loss: 0.87392, val-r2: -1.56690, val-mae: 0.37809
# EarlyStopping counter: 1/5
# Эпоха [3/50], train-loss: 0.53379, train-r2: -4.02297, val-loss: 0.80365, val-r2: -1.48482, val-mae: 0.37337
# EarlyStopping counter: 2/5
# Эпоха [4/50], train-loss: 0.39277, train-r2: -4.25809, val-loss: 0.76789, val-r2: -1.44844, val-mae: 0.37096
# EarlyStopping counter: 3/5
# Эпоха [5/50], train-loss: 0.30537, train-r2: -3.73893, val-loss: 0.72788, val-r2: -1.39074, val-mae: 0.36792
# EarlyStopping counter: 4/5
# Эпоха [6/50], train-loss: 0.24829, train-r2: -3.70106, val-loss: 0.71143, val-r2: -1.37848, val-mae: 0.36716
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 6
# Эпоха [1/50], train-loss: 1.37283, train-r2: -4.42883, val-loss: 1.07539, val-r2: -1.43636, val-mae: 0.36730
# Эпоха [2/50], train-loss: 0.79670, train-r2: -3.83610, val-loss: 0.91737, val-r2: -1.34584, val-mae: 0.36303
# EarlyStopping counter: 1/5
# Эпоха [3/50], train-loss: 0.54371, train-r2: -3.99027, val-loss: 0.82958, val-r2: -1.31078, val-mae: 0.36163
# EarlyStopping counter: 2/5
# Эпоха [4/50], train-loss: 0.40143, train-r2: -4.01188, val-loss: 0.77202, val-r2: -1.29042, val-mae: 0.36078
# EarlyStopping counter: 3/5
# Эпоха [5/50], train-loss: 0.30707, train-r2: -4.03486, val-loss: 0.73387, val-r2: -1.27720, val-mae: 0.35998
# EarlyStopping counter: 4/5
# Эпоха [6/50], train-loss: 0.24555, train-r2: -3.36578, val-loss: 0.71293, val-r2: -1.24176, val-mae: 0.35763
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 6
# Эпоха [1/50], train-loss: 0.69741, train-r2: -3.75630, val-loss: 0.24828, val-r2: -1.70507, val-mae: 0.38902
# Эпоха [2/50], train-loss: 0.21189, train-r2: -3.65869, val-loss: 0.16826, val-r2: -1.71428, val-mae: 0.39446
# Эпоха [3/50], train-loss: 0.18239, train-r2: -3.38869, val-loss: 0.15322, val-r2: -1.78236, val-mae: 0.39966
# Эпоха [4/50], train-loss: 0.17530, train-r2: -3.90053, val-loss: 0.17190, val-r2: -1.79004, val-mae: 0.39802
# Эпоха [5/50], train-loss: 0.20942, train-r2: -3.78658, val-loss: 0.20736, val-r2: -1.76077, val-mae: 0.39739
# EarlyStopping counter: 1/5
# Эпоха [6/50], train-loss: 0.25494, train-r2: -3.93687, val-loss: 0.27752, val-r2: -1.81930, val-mae: 0.39811
# Эпоха [7/50], train-loss: 0.28428, train-r2: -4.32350, val-loss: 0.25929, val-r2: -1.81876, val-mae: 0.39909
# EarlyStopping counter: 1/5
# Эпоха [8/50], train-loss: 0.26100, train-r2: -3.78657, val-loss: 0.25528, val-r2: -1.80368, val-mae: 0.39568
# EarlyStopping counter: 2/5
# Эпоха [9/50], train-loss: 0.20977, train-r2: -4.56760, val-loss: 0.18824, val-r2: -1.67885, val-mae: 0.39094
# EarlyStopping counter: 3/5
# Эпоха [10/50], train-loss: 0.19898, train-r2: -4.04479, val-loss: 0.18988, val-r2: -1.76208, val-mae: 0.39595
# EarlyStopping counter: 4/5
# Эпоха [11/50], train-loss: 0.18831, train-r2: -3.84682, val-loss: 0.15995, val-r2: -1.75308, val-mae: 0.39719
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 11

# %% [markdown]
# Подберем и обучим модель нейронной сети.

# %%
best_nn_model = None    # Лучшая модель на кроссвалидации
best_nn_metric = -1000  # Лучшая метрика R2 на кроссвалидации
best_nn_metric_2 = 0    # Лучшая метрика MAE на кроссвалидации
best_nn_params = {}     # Лучшие гиперпараметры на кроссвалидации

# Вложенные циклы перебора гиперпараметров с кроссвалидацией
for hidden_size in nn_train_params['hidden_size']:
    for dropout_fraction in nn_train_params['dropout_fraction']:
        for learning_rate in nn_train_params['learning_rate']:
            print(f'Testing parameters: hidden_size={hidden_size}, '
                  f'dropout_fraction={dropout_fraction}, learning_rate={learning_rate}')

            gss = GroupShuffleSplit(n_splits=n_splits, test_size=TEST_SIZE, random_state=RANDOM_STATE)
            best_metrics = []
            best_metrics_2 = []
            # Цикл кроссвалидации
            for train_indices, val_indices in gss.split(train_df, groups=train_df['image']):
                train_loader, val_loader = load_data(train_df, train_indices, val_indices)
                _, best_score, best_score_2 = init_train_model( architecture='nn',
                                                                hidden_size=hidden_size,
                                                                dropout_fraction=dropout_fraction,
                                                                learning_rate=learning_rate,
                                                                train_loader=train_loader,
                                                                val_loader=val_loader)
                best_metrics.append(best_score)
                best_metrics_2.append(best_score_2)
            # Сохраняем лучшие средние значения метрик на кроссвалидации и соответствующие им гиперпараметры
            if sum(best_metrics)/n_splits > best_nn_metric:
                best_nn_metric = sum(best_metrics)/n_splits
                best_nn_metric_2 = sum(best_metrics_2)/n_splits
                best_nn_params['dropout_fraction'] = dropout_fraction
                best_nn_params['hidden_size'] = hidden_size
                best_nn_params['learning_rate'] = learning_rate

# Обучаем модель с лучшими гиперпараметрами
train_loader, _ = load_data(train_df, train_df.index)
best_nn_model, best_nn_score, best_nn_score_2 = init_train_model( architecture='nn',
                                                            train_loader=train_loader,
                                                            val_loader=None,
                                                            **best_nn_params)
# Out:
# Testing parameters: hidden_size=512, dropout_fraction=0.0, learning_rate=0.001
# Эпоха [1/50], train-loss: 0.49929, train-r2: -0.31744, val-loss: 0.43380, val-r2: 0.24626, val-mae: 0.16801
# Эпоха [2/50], train-loss: 0.40879, train-r2: 0.24908, val-loss: 0.41437, val-r2: 0.33800, val-mae: 0.14341
# Эпоха [3/50], train-loss: 0.37787, train-r2: 0.44941, val-loss: 0.41262, val-r2: 0.37313, val-mae: 0.13516
# Эпоха [4/50], train-loss: 0.35875, train-r2: 0.57448, val-loss: 0.41585, val-r2: 0.33512, val-mae: 0.13975
# EarlyStopping counter: 1/5
# Эпоха [5/50], train-loss: 0.34980, train-r2: 0.59574, val-loss: 0.41372, val-r2: 0.35246, val-mae: 0.14068
# EarlyStopping counter: 2/5
# Эпоха [6/50], train-loss: 0.34302, train-r2: 0.63820, val-loss: 0.41511, val-r2: 0.33402, val-mae: 0.14155
# EarlyStopping counter: 3/5
# Эпоха [7/50], train-loss: 0.33977, train-r2: 0.70239, val-loss: 0.40799, val-r2: 0.37983, val-mae: 0.13710
# Эпоха [8/50], train-loss: 0.33516, train-r2: 0.66849, val-loss: 0.40920, val-r2: 0.40408, val-mae: 0.12662
# Эпоха [9/50], train-loss: 0.33341, train-r2: 0.69853, val-loss: 0.40725, val-r2: 0.38877, val-mae: 0.13000
# EarlyStopping counter: 1/5
# Эпоха [10/50], train-loss: 0.33008, train-r2: 0.75478, val-loss: 0.40601, val-r2: 0.38798, val-mae: 0.13174
# EarlyStopping counter: 2/5
# Эпоха [11/50], train-loss: 0.32609, train-r2: 0.74504, val-loss: 0.41383, val-r2: 0.34548, val-mae: 0.13665
# EarlyStopping counter: 3/5
# Эпоха [12/50], train-loss: 0.32529, train-r2: 0.74522, val-loss: 0.41210, val-r2: 0.36790, val-mae: 0.13538
# EarlyStopping counter: 4/5
# Эпоха [13/50], train-loss: 0.32422, train-r2: 0.77473, val-loss: 0.40846, val-r2: 0.37710, val-mae: 0.13327
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 13
# Эпоха [1/50], train-loss: 0.49308, train-r2: -0.29732, val-loss: 0.46142, val-r2: 0.29742, val-mae: 0.15990
# Эпоха [2/50], train-loss: 0.39475, train-r2: 0.23976, val-loss: 0.44640, val-r2: 0.36160, val-mae: 0.15247
# Эпоха [3/50], train-loss: 0.36914, train-r2: 0.42092, val-loss: 0.45061, val-r2: 0.33441, val-mae: 0.15646
# EarlyStopping counter: 1/5
# Эпоха [4/50], train-loss: 0.34973, train-r2: 0.45866, val-loss: 0.44640, val-r2: 0.37948, val-mae: 0.14462
# Эпоха [5/50], train-loss: 0.34168, train-r2: 0.56271, val-loss: 0.44117, val-r2: 0.37743, val-mae: 0.14762
# EarlyStopping counter: 1/5
# Эпоха [6/50], train-loss: 0.33609, train-r2: 0.61831, val-loss: 0.43784, val-r2: 0.42559, val-mae: 0.13859
# Эпоха [7/50], train-loss: 0.32956, train-r2: 0.67576, val-loss: 0.43785, val-r2: 0.42021, val-mae: 0.13849
# EarlyStopping counter: 1/5
# Эпоха [8/50], train-loss: 0.32551, train-r2: 0.70398, val-loss: 0.43984, val-r2: 0.41094, val-mae: 0.13480
# EarlyStopping counter: 2/5
# Эпоха [9/50], train-loss: 0.32051, train-r2: 0.69904, val-loss: 0.44742, val-r2: 0.37131, val-mae: 0.14167
# EarlyStopping counter: 3/5
# Эпоха [10/50], train-loss: 0.31783, train-r2: 0.70564, val-loss: 0.43735, val-r2: 0.42373, val-mae: 0.13428
# EarlyStopping counter: 4/5
# Эпоха [11/50], train-loss: 0.31676, train-r2: 0.63508, val-loss: 0.44573, val-r2: 0.38512, val-mae: 0.14106
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 11
# Эпоха [1/50], train-loss: 0.49649, train-r2: -0.23449, val-loss: 0.45936, val-r2: 0.24346, val-mae: 0.15679
# Эпоха [2/50], train-loss: 0.40224, train-r2: 0.23294, val-loss: 0.44985, val-r2: 0.29148, val-mae: 0.15615
# Эпоха [3/50], train-loss: 0.37444, train-r2: 0.39515, val-loss: 0.44848, val-r2: 0.28047, val-mae: 0.15768
# EarlyStopping counter: 1/5
# Эпоха [4/50], train-loss: 0.36105, train-r2: 0.45240, val-loss: 0.44053, val-r2: 0.32739, val-mae: 0.15062
# Эпоха [5/50], train-loss: 0.35042, train-r2: 0.61156, val-loss: 0.43748, val-r2: 0.32974, val-mae: 0.14389
# EarlyStopping counter: 1/5
# Эпоха [6/50], train-loss: 0.34692, train-r2: 0.63932, val-loss: 0.44127, val-r2: 0.33919, val-mae: 0.14562
# Эпоха [7/50], train-loss: 0.33385, train-r2: 0.69095, val-loss: 0.44619, val-r2: 0.32592, val-mae: 0.14256
# EarlyStopping counter: 1/5
# Эпоха [8/50], train-loss: 0.33245, train-r2: 0.70421, val-loss: 0.43858, val-r2: 0.34559, val-mae: 0.14132
# Эпоха [9/50], train-loss: 0.32896, train-r2: 0.74053, val-loss: 0.43900, val-r2: 0.33577, val-mae: 0.14571
# EarlyStopping counter: 1/5
# Эпоха [10/50], train-loss: 0.32931, train-r2: 0.71165, val-loss: 0.43621, val-r2: 0.35254, val-mae: 0.14313
# Эпоха [11/50], train-loss: 0.32583, train-r2: 0.75361, val-loss: 0.43832, val-r2: 0.35981, val-mae: 0.14007
# Эпоха [12/50], train-loss: 0.32331, train-r2: 0.75342, val-loss: 0.43876, val-r2: 0.32759, val-mae: 0.14754
# EarlyStopping counter: 1/5
# Эпоха [13/50], train-loss: 0.31947, train-r2: 0.78727, val-loss: 0.43290, val-r2: 0.35920, val-mae: 0.14328
# EarlyStopping counter: 2/5
# Эпоха [14/50], train-loss: 0.32007, train-r2: 0.77307, val-loss: 0.45082, val-r2: 0.28876, val-mae: 0.15248
# EarlyStopping counter: 3/5
# Эпоха [15/50], train-loss: 0.32148, train-r2: 0.74431, val-loss: 0.44361, val-r2: 0.33327, val-mae: 0.14321
# EarlyStopping counter: 4/5
# Эпоха [16/50], train-loss: 0.31935, train-r2: 0.77431, val-loss: 0.44608, val-r2: 0.31866, val-mae: 0.14886
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 16
# Testing parameters: hidden_size=512, dropout_fraction=0.0, learning_rate=0.0001
# Эпоха [1/50], train-loss: 0.49834, train-r2: -0.48962, val-loss: 0.44984, val-r2: 0.14106, val-mae: 0.17482
# Эпоха [2/50], train-loss: 0.39228, train-r2: 0.37859, val-loss: 0.42689, val-r2: 0.28894, val-mae: 0.15187
# Эпоха [3/50], train-loss: 0.36457, train-r2: 0.46733, val-loss: 0.42311, val-r2: 0.30862, val-mae: 0.14758
# Эпоха [4/50], train-loss: 0.34555, train-r2: 0.65940, val-loss: 0.41719, val-r2: 0.34163, val-mae: 0.14086
# Эпоха [5/50], train-loss: 0.33273, train-r2: 0.70532, val-loss: 0.42247, val-r2: 0.29823, val-mae: 0.14601
# EarlyStopping counter: 1/5
# Эпоха [6/50], train-loss: 0.33001, train-r2: 0.72442, val-loss: 0.42090, val-r2: 0.30975, val-mae: 0.14142
# EarlyStopping counter: 2/5
# Эпоха [7/50], train-loss: 0.32625, train-r2: 0.75425, val-loss: 0.42006, val-r2: 0.32650, val-mae: 0.13858
# EarlyStopping counter: 3/5
# Эпоха [8/50], train-loss: 0.32149, train-r2: 0.79304, val-loss: 0.41740, val-r2: 0.33669, val-mae: 0.13837
# EarlyStopping counter: 4/5
# Эпоха [9/50], train-loss: 0.32136, train-r2: 0.77709, val-loss: 0.41511, val-r2: 0.36241, val-mae: 0.13293
# Эпоха [10/50], train-loss: 0.32170, train-r2: 0.80102, val-loss: 0.41537, val-r2: 0.36008, val-mae: 0.13501
# EarlyStopping counter: 1/5
# Эпоха [11/50], train-loss: 0.32300, train-r2: 0.78673, val-loss: 0.41508, val-r2: 0.36209, val-mae: 0.13351
# EarlyStopping counter: 2/5
# Эпоха [12/50], train-loss: 0.31833, train-r2: 0.79540, val-loss: 0.40906, val-r2: 0.38280, val-mae: 0.13022
# Эпоха [13/50], train-loss: 0.31912, train-r2: 0.76827, val-loss: 0.40801, val-r2: 0.39150, val-mae: 0.12971
# Эпоха [14/50], train-loss: 0.31610, train-r2: 0.79596, val-loss: 0.41124, val-r2: 0.36790, val-mae: 0.13270
# EarlyStopping counter: 1/5
# Эпоха [15/50], train-loss: 0.31567, train-r2: 0.80476, val-loss: 0.40920, val-r2: 0.37583, val-mae: 0.13179
# EarlyStopping counter: 2/5
# Эпоха [16/50], train-loss: 0.31634, train-r2: 0.81259, val-loss: 0.41040, val-r2: 0.38210, val-mae: 0.12882
# EarlyStopping counter: 3/5
# Эпоха [17/50], train-loss: 0.31391, train-r2: 0.83044, val-loss: 0.40813, val-r2: 0.38597, val-mae: 0.13177
# EarlyStopping counter: 4/5
# Эпоха [18/50], train-loss: 0.31470, train-r2: 0.74961, val-loss: 0.40945, val-r2: 0.38824, val-mae: 0.12816
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 18
# Эпоха [1/50], train-loss: 0.46671, train-r2: -0.22809, val-loss: 0.48311, val-r2: 0.20325, val-mae: 0.17538
# Эпоха [2/50], train-loss: 0.37809, train-r2: 0.34743, val-loss: 0.46957, val-r2: 0.26729, val-mae: 0.16581
# Эпоха [3/50], train-loss: 0.34795, train-r2: 0.56251, val-loss: 0.45723, val-r2: 0.34043, val-mae: 0.15417
# Эпоха [4/50], train-loss: 0.33332, train-r2: 0.66158, val-loss: 0.46116, val-r2: 0.32897, val-mae: 0.14885
# EarlyStopping counter: 1/5
# Эпоха [5/50], train-loss: 0.32350, train-r2: 0.73533, val-loss: 0.45885, val-r2: 0.33482, val-mae: 0.15152
# EarlyStopping counter: 2/5
# Эпоха [6/50], train-loss: 0.31742, train-r2: 0.75240, val-loss: 0.46023, val-r2: 0.32983, val-mae: 0.15153
# EarlyStopping counter: 3/5
# Эпоха [7/50], train-loss: 0.31371, train-r2: 0.77279, val-loss: 0.45970, val-r2: 0.32873, val-mae: 0.14887
# EarlyStopping counter: 4/5
# Эпоха [8/50], train-loss: 0.31410, train-r2: 0.73534, val-loss: 0.45657, val-r2: 0.34312, val-mae: 0.15047
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 8
# Эпоха [1/50], train-loss: 0.58228, train-r2: -1.88776, val-loss: 0.47205, val-r2: 0.17078, val-mae: 0.18723
# Эпоха [2/50], train-loss: 0.39147, train-r2: 0.24079, val-loss: 0.46262, val-r2: 0.23293, val-mae: 0.16640
# Эпоха [3/50], train-loss: 0.35614, train-r2: 0.55773, val-loss: 0.45392, val-r2: 0.27539, val-mae: 0.15852
# Эпоха [4/50], train-loss: 0.34139, train-r2: 0.64389, val-loss: 0.45596, val-r2: 0.26563, val-mae: 0.15902
# EarlyStopping counter: 1/5
# Эпоха [5/50], train-loss: 0.33113, train-r2: 0.72021, val-loss: 0.45115, val-r2: 0.29856, val-mae: 0.15140
# Эпоха [6/50], train-loss: 0.32392, train-r2: 0.75109, val-loss: 0.45213, val-r2: 0.28780, val-mae: 0.15241
# EarlyStopping counter: 1/5
# Эпоха [7/50], train-loss: 0.32205, train-r2: 0.74164, val-loss: 0.46093, val-r2: 0.27409, val-mae: 0.14951
# EarlyStopping counter: 2/5
# Эпоха [8/50], train-loss: 0.32161, train-r2: 0.76872, val-loss: 0.46376, val-r2: 0.27233, val-mae: 0.14905
# EarlyStopping counter: 3/5
# Эпоха [9/50], train-loss: 0.32030, train-r2: 0.77023, val-loss: 0.44838, val-r2: 0.30969, val-mae: 0.14799
# Эпоха [10/50], train-loss: 0.31780, train-r2: 0.79383, val-loss: 0.44667, val-r2: 0.32052, val-mae: 0.14772
# Эпоха [11/50], train-loss: 0.31661, train-r2: 0.78872, val-loss: 0.44569, val-r2: 0.32148, val-mae: 0.14625
# EarlyStopping counter: 1/5
# Эпоха [12/50], train-loss: 0.31392, train-r2: 0.81170, val-loss: 0.45612, val-r2: 0.29685, val-mae: 0.14471
# EarlyStopping counter: 2/5
# Эпоха [13/50], train-loss: 0.31688, train-r2: 0.76833, val-loss: 0.44876, val-r2: 0.31171, val-mae: 0.14452
# EarlyStopping counter: 3/5
# Эпоха [14/50], train-loss: 0.31340, train-r2: 0.81716, val-loss: 0.45064, val-r2: 0.30286, val-mae: 0.14548
# EarlyStopping counter: 4/5
# Эпоха [15/50], train-loss: 0.31360, train-r2: 0.79757, val-loss: 0.44674, val-r2: 0.32334, val-mae: 0.14494
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 15
# Testing parameters: hidden_size=512, dropout_fraction=0.2, learning_rate=0.001
# Эпоха [1/50], train-loss: 0.50772, train-r2: -0.25524, val-loss: 0.42473, val-r2: 0.30005, val-mae: 0.14466
# Эпоха [2/50], train-loss: 0.42600, train-r2: 0.14958, val-loss: 0.42674, val-r2: 0.26986, val-mae: 0.15397
# EarlyStopping counter: 1/5
# Эпоха [3/50], train-loss: 0.39679, train-r2: 0.27492, val-loss: 0.42551, val-r2: 0.27673, val-mae: 0.15745
# EarlyStopping counter: 2/5
# Эпоха [4/50], train-loss: 0.38391, train-r2: 0.33173, val-loss: 0.41729, val-r2: 0.32360, val-mae: 0.14348
# Эпоха [5/50], train-loss: 0.36931, train-r2: 0.53317, val-loss: 0.42191, val-r2: 0.29167, val-mae: 0.14824
# EarlyStopping counter: 1/5
# Эпоха [6/50], train-loss: 0.36298, train-r2: 0.52238, val-loss: 0.41309, val-r2: 0.33809, val-mae: 0.13549
# Эпоха [7/50], train-loss: 0.35913, train-r2: 0.43640, val-loss: 0.40592, val-r2: 0.37958, val-mae: 0.13340
# Эпоха [8/50], train-loss: 0.35489, train-r2: 0.53046, val-loss: 0.41317, val-r2: 0.34670, val-mae: 0.13884
# EarlyStopping counter: 1/5
# Эпоха [9/50], train-loss: 0.34831, train-r2: 0.63407, val-loss: 0.40434, val-r2: 0.38891, val-mae: 0.13254
# Эпоха [10/50], train-loss: 0.34214, train-r2: 0.68493, val-loss: 0.40214, val-r2: 0.41250, val-mae: 0.13036
# Эпоха [11/50], train-loss: 0.34070, train-r2: 0.66295, val-loss: 0.40747, val-r2: 0.39988, val-mae: 0.12525
# EarlyStopping counter: 1/5
# Эпоха [12/50], train-loss: 0.33715, train-r2: 0.66526, val-loss: 0.40252, val-r2: 0.40758, val-mae: 0.12611
# EarlyStopping counter: 2/5
# Эпоха [13/50], train-loss: 0.33591, train-r2: 0.67772, val-loss: 0.40689, val-r2: 0.38412, val-mae: 0.13137
# EarlyStopping counter: 3/5
# Эпоха [14/50], train-loss: 0.33380, train-r2: 0.69187, val-loss: 0.41008, val-r2: 0.36394, val-mae: 0.13517
# EarlyStopping counter: 4/5
# Эпоха [15/50], train-loss: 0.33250, train-r2: 0.68196, val-loss: 0.41041, val-r2: 0.37123, val-mae: 0.13128
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 15
# Эпоха [1/50], train-loss: 0.48763, train-r2: -0.48602, val-loss: 0.50243, val-r2: 0.08855, val-mae: 0.18905
# Эпоха [2/50], train-loss: 0.41628, train-r2: 0.04632, val-loss: 0.45782, val-r2: 0.31891, val-mae: 0.16145
# Эпоха [3/50], train-loss: 0.38929, train-r2: 0.28333, val-loss: 0.47167, val-r2: 0.21710, val-mae: 0.17801
# EarlyStopping counter: 1/5
# Эпоха [4/50], train-loss: 0.37137, train-r2: 0.39701, val-loss: 0.45445, val-r2: 0.33388, val-mae: 0.15621
# Эпоха [5/50], train-loss: 0.36202, train-r2: 0.43159, val-loss: 0.45427, val-r2: 0.31706, val-mae: 0.16314
# EarlyStopping counter: 1/5
# Эпоха [6/50], train-loss: 0.34789, train-r2: 0.57344, val-loss: 0.45035, val-r2: 0.36343, val-mae: 0.14931
# Эпоха [7/50], train-loss: 0.34498, train-r2: 0.54881, val-loss: 0.45420, val-r2: 0.34103, val-mae: 0.15315
# EarlyStopping counter: 1/5
# Эпоха [8/50], train-loss: 0.34322, train-r2: 0.57376, val-loss: 0.44752, val-r2: 0.38630, val-mae: 0.14418
# Эпоха [9/50], train-loss: 0.33333, train-r2: 0.66377, val-loss: 0.45162, val-r2: 0.36455, val-mae: 0.14932
# EarlyStopping counter: 1/5
# Эпоха [10/50], train-loss: 0.32846, train-r2: 0.71454, val-loss: 0.44761, val-r2: 0.38611, val-mae: 0.14420
# EarlyStopping counter: 2/5
# Эпоха [11/50], train-loss: 0.32894, train-r2: 0.62600, val-loss: 0.45567, val-r2: 0.35036, val-mae: 0.15175
# EarlyStopping counter: 3/5
# Эпоха [12/50], train-loss: 0.32738, train-r2: 0.67287, val-loss: 0.44238, val-r2: 0.40518, val-mae: 0.14306
# Эпоха [13/50], train-loss: 0.32452, train-r2: 0.71288, val-loss: 0.44732, val-r2: 0.38465, val-mae: 0.14416
# EarlyStopping counter: 1/5
# Эпоха [14/50], train-loss: 0.32438, train-r2: 0.69737, val-loss: 0.45174, val-r2: 0.36768, val-mae: 0.14600
# EarlyStopping counter: 2/5
# Эпоха [15/50], train-loss: 0.32263, train-r2: 0.71741, val-loss: 0.44532, val-r2: 0.40063, val-mae: 0.14205
# EarlyStopping counter: 3/5
# Эпоха [16/50], train-loss: 0.32102, train-r2: 0.71543, val-loss: 0.44779, val-r2: 0.39112, val-mae: 0.14171
# EarlyStopping counter: 4/5
# Эпоха [17/50], train-loss: 0.31745, train-r2: 0.75125, val-loss: 0.45170, val-r2: 0.37947, val-mae: 0.14162
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 17
# Эпоха [1/50], train-loss: 0.49430, train-r2: -0.26304, val-loss: 0.46907, val-r2: 0.16868, val-mae: 0.18537
# Эпоха [2/50], train-loss: 0.41913, train-r2: 0.17107, val-loss: 0.44450, val-r2: 0.28576, val-mae: 0.16671
# Эпоха [3/50], train-loss: 0.39693, train-r2: 0.25461, val-loss: 0.44496, val-r2: 0.32030, val-mae: 0.15045
# Эпоха [4/50], train-loss: 0.37643, train-r2: 0.39969, val-loss: 0.44341, val-r2: 0.31253, val-mae: 0.15085
# EarlyStopping counter: 1/5
# Эпоха [5/50], train-loss: 0.36377, train-r2: 0.54075, val-loss: 0.43779, val-r2: 0.33934, val-mae: 0.15064
# Эпоха [6/50], train-loss: 0.35508, train-r2: 0.57251, val-loss: 0.43726, val-r2: 0.33896, val-mae: 0.14904
# EarlyStopping counter: 1/5
# Эпоха [7/50], train-loss: 0.35235, train-r2: 0.49940, val-loss: 0.43985, val-r2: 0.34159, val-mae: 0.14729
# EarlyStopping counter: 2/5
# Эпоха [8/50], train-loss: 0.34578, train-r2: 0.58429, val-loss: 0.43993, val-r2: 0.34474, val-mae: 0.14641
# Эпоха [9/50], train-loss: 0.34179, train-r2: 0.63563, val-loss: 0.43988, val-r2: 0.33968, val-mae: 0.14531
# EarlyStopping counter: 1/5
# Эпоха [10/50], train-loss: 0.33974, train-r2: 0.66663, val-loss: 0.43753, val-r2: 0.34072, val-mae: 0.14703
# EarlyStopping counter: 2/5
# Эпоха [11/50], train-loss: 0.33758, train-r2: 0.65617, val-loss: 0.43785, val-r2: 0.34717, val-mae: 0.14393
# EarlyStopping counter: 3/5
# Эпоха [12/50], train-loss: 0.33320, train-r2: 0.68984, val-loss: 0.44422, val-r2: 0.32174, val-mae: 0.14830
# EarlyStopping counter: 4/5
# Эпоха [13/50], train-loss: 0.33438, train-r2: 0.66423, val-loss: 0.43994, val-r2: 0.35032, val-mae: 0.14280
# Эпоха [14/50], train-loss: 0.33182, train-r2: 0.71005, val-loss: 0.44402, val-r2: 0.33721, val-mae: 0.14327
# EarlyStopping counter: 1/5
# Эпоха [15/50], train-loss: 0.32946, train-r2: 0.70244, val-loss: 0.44559, val-r2: 0.32038, val-mae: 0.14766
# EarlyStopping counter: 2/5
# Эпоха [16/50], train-loss: 0.32548, train-r2: 0.72862, val-loss: 0.43260, val-r2: 0.37101, val-mae: 0.13944
# Эпоха [17/50], train-loss: 0.32724, train-r2: 0.70449, val-loss: 0.43972, val-r2: 0.34449, val-mae: 0.14793
# EarlyStopping counter: 1/5
# Эпоха [18/50], train-loss: 0.32666, train-r2: 0.75033, val-loss: 0.44318, val-r2: 0.34681, val-mae: 0.14296
# EarlyStopping counter: 2/5
# Эпоха [19/50], train-loss: 0.32415, train-r2: 0.73903, val-loss: 0.44525, val-r2: 0.31794, val-mae: 0.14969
# EarlyStopping counter: 3/5
# Эпоха [20/50], train-loss: 0.32361, train-r2: 0.74562, val-loss: 0.44300, val-r2: 0.35742, val-mae: 0.14180
# EarlyStopping counter: 4/5
# Эпоха [21/50], train-loss: 0.32312, train-r2: 0.78597, val-loss: 0.44702, val-r2: 0.32305, val-mae: 0.14553
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 21
# Testing parameters: hidden_size=512, dropout_fraction=0.2, learning_rate=0.0001
# Эпоха [1/50], train-loss: 0.53633, train-r2: -1.01312, val-loss: 0.48371, val-r2: -0.06125, val-mae: 0.20627
# Эпоха [2/50], train-loss: 0.43425, train-r2: 0.04727, val-loss: 0.44686, val-r2: 0.16735, val-mae: 0.17318
# Эпоха [3/50], train-loss: 0.40158, train-r2: 0.31188, val-loss: 0.43962, val-r2: 0.19735, val-mae: 0.16596
# Эпоха [4/50], train-loss: 0.38833, train-r2: 0.39215, val-loss: 0.43686, val-r2: 0.20760, val-mae: 0.16574
# Эпоха [5/50], train-loss: 0.37526, train-r2: 0.45468, val-loss: 0.42796, val-r2: 0.25770, val-mae: 0.15519
# Эпоха [6/50], train-loss: 0.37039, train-r2: 0.49285, val-loss: 0.43407, val-r2: 0.21744, val-mae: 0.15973
# EarlyStopping counter: 1/5
# Эпоха [7/50], train-loss: 0.36201, train-r2: 0.49380, val-loss: 0.42547, val-r2: 0.27035, val-mae: 0.15305
# Эпоха [8/50], train-loss: 0.35340, train-r2: 0.58612, val-loss: 0.42232, val-r2: 0.28799, val-mae: 0.14867
# Эпоха [9/50], train-loss: 0.35497, train-r2: 0.57628, val-loss: 0.42192, val-r2: 0.29585, val-mae: 0.14822
# Эпоха [10/50], train-loss: 0.35036, train-r2: 0.59885, val-loss: 0.42119, val-r2: 0.29908, val-mae: 0.14350
# EarlyStopping counter: 1/5
# Эпоха [11/50], train-loss: 0.34703, train-r2: 0.60783, val-loss: 0.42485, val-r2: 0.27358, val-mae: 0.14764
# EarlyStopping counter: 2/5
# Эпоха [12/50], train-loss: 0.34464, train-r2: 0.64906, val-loss: 0.42505, val-r2: 0.27828, val-mae: 0.15066
# EarlyStopping counter: 3/5
# Эпоха [13/50], train-loss: 0.34336, train-r2: 0.64386, val-loss: 0.42316, val-r2: 0.29320, val-mae: 0.14435
# EarlyStopping counter: 4/5
# Эпоха [14/50], train-loss: 0.33799, train-r2: 0.68637, val-loss: 0.42509, val-r2: 0.28971, val-mae: 0.14530
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 14
# Эпоха [1/50], train-loss: 0.57520, train-r2: -1.93297, val-loss: 0.50209, val-r2: 0.10191, val-mae: 0.20386
# Эпоха [2/50], train-loss: 0.42814, train-r2: -0.01674, val-loss: 0.48029, val-r2: 0.21166, val-mae: 0.18158
# Эпоха [3/50], train-loss: 0.39929, train-r2: 0.12681, val-loss: 0.46975, val-r2: 0.26850, val-mae: 0.17369
# Эпоха [4/50], train-loss: 0.37787, train-r2: 0.33915, val-loss: 0.46738, val-r2: 0.28730, val-mae: 0.16498
# Эпоха [5/50], train-loss: 0.36788, train-r2: 0.42101, val-loss: 0.46181, val-r2: 0.31652, val-mae: 0.15740
# Эпоха [6/50], train-loss: 0.35616, train-r2: 0.45405, val-loss: 0.45763, val-r2: 0.32078, val-mae: 0.16416
# EarlyStopping counter: 1/5
# Эпоха [7/50], train-loss: 0.35096, train-r2: 0.51304, val-loss: 0.46297, val-r2: 0.29322, val-mae: 0.16812
# EarlyStopping counter: 2/5
# Эпоха [8/50], train-loss: 0.34970, train-r2: 0.52624, val-loss: 0.46027, val-r2: 0.30726, val-mae: 0.16207
# EarlyStopping counter: 3/5
# Эпоха [9/50], train-loss: 0.34087, train-r2: 0.57228, val-loss: 0.45847, val-r2: 0.32291, val-mae: 0.15910
# Эпоха [10/50], train-loss: 0.33880, train-r2: 0.60819, val-loss: 0.45432, val-r2: 0.34166, val-mae: 0.15610
# Эпоха [11/50], train-loss: 0.33576, train-r2: 0.60904, val-loss: 0.45431, val-r2: 0.35057, val-mae: 0.15289
# Эпоха [12/50], train-loss: 0.33266, train-r2: 0.60431, val-loss: 0.45360, val-r2: 0.34042, val-mae: 0.15678
# EarlyStopping counter: 1/5
# Эпоха [13/50], train-loss: 0.32924, train-r2: 0.63009, val-loss: 0.45432, val-r2: 0.34199, val-mae: 0.15760
# EarlyStopping counter: 2/5
# Эпоха [14/50], train-loss: 0.32719, train-r2: 0.64605, val-loss: 0.46076, val-r2: 0.30693, val-mae: 0.15796
# EarlyStopping counter: 3/5
# Эпоха [15/50], train-loss: 0.33017, train-r2: 0.64692, val-loss: 0.45323, val-r2: 0.34628, val-mae: 0.15344
# EarlyStopping counter: 4/5
# Эпоха [16/50], train-loss: 0.32680, train-r2: 0.65566, val-loss: 0.45689, val-r2: 0.32796, val-mae: 0.15832
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 16
# Эпоха [1/50], train-loss: 0.53450, train-r2: -1.12371, val-loss: 0.48252, val-r2: 0.12061, val-mae: 0.19579
# Эпоха [2/50], train-loss: 0.42668, train-r2: -0.14143, val-loss: 0.46956, val-r2: 0.18893, val-mae: 0.18025
# Эпоха [3/50], train-loss: 0.40019, train-r2: 0.26501, val-loss: 0.46037, val-r2: 0.23113, val-mae: 0.17310
# Эпоха [4/50], train-loss: 0.38328, train-r2: 0.40839, val-loss: 0.45557, val-r2: 0.25718, val-mae: 0.16529
# Эпоха [5/50], train-loss: 0.36897, train-r2: 0.45059, val-loss: 0.45612, val-r2: 0.25240, val-mae: 0.16712
# EarlyStopping counter: 1/5
# Эпоха [6/50], train-loss: 0.36024, train-r2: 0.50578, val-loss: 0.46119, val-r2: 0.23229, val-mae: 0.16592
# EarlyStopping counter: 2/5
# Эпоха [7/50], train-loss: 0.35679, train-r2: 0.50430, val-loss: 0.45500, val-r2: 0.24953, val-mae: 0.16723
# EarlyStopping counter: 3/5
# Эпоха [8/50], train-loss: 0.35416, train-r2: 0.53309, val-loss: 0.46009, val-r2: 0.23517, val-mae: 0.16755
# EarlyStopping counter: 4/5
# Эпоха [9/50], train-loss: 0.34691, train-r2: 0.60967, val-loss: 0.44983, val-r2: 0.28138, val-mae: 0.15834
# Эпоха [10/50], train-loss: 0.34201, train-r2: 0.62189, val-loss: 0.45426, val-r2: 0.25782, val-mae: 0.16161
# EarlyStopping counter: 1/5
# Эпоха [11/50], train-loss: 0.34315, train-r2: 0.58954, val-loss: 0.45065, val-r2: 0.29191, val-mae: 0.15359
# Эпоха [12/50], train-loss: 0.33888, train-r2: 0.64442, val-loss: 0.45340, val-r2: 0.26191, val-mae: 0.16069
# EarlyStopping counter: 1/5
# Эпоха [13/50], train-loss: 0.33618, train-r2: 0.66279, val-loss: 0.44909, val-r2: 0.27974, val-mae: 0.15842
# EarlyStopping counter: 2/5
# Эпоха [14/50], train-loss: 0.33394, train-r2: 0.64324, val-loss: 0.45091, val-r2: 0.29952, val-mae: 0.15006
# Эпоха [15/50], train-loss: 0.33140, train-r2: 0.69385, val-loss: 0.45168, val-r2: 0.27479, val-mae: 0.15434
# EarlyStopping counter: 1/5
# Эпоха [16/50], train-loss: 0.33109, train-r2: 0.71810, val-loss: 0.44524, val-r2: 0.29943, val-mae: 0.15346
# EarlyStopping counter: 2/5
# Эпоха [17/50], train-loss: 0.33297, train-r2: 0.63725, val-loss: 0.44776, val-r2: 0.29310, val-mae: 0.15212
# EarlyStopping counter: 3/5
# Эпоха [18/50], train-loss: 0.32896, train-r2: 0.64078, val-loss: 0.44503, val-r2: 0.30299, val-mae: 0.15259
# EarlyStopping counter: 4/5
# Эпоха [19/50], train-loss: 0.33275, train-r2: 0.65457, val-loss: 0.44687, val-r2: 0.30205, val-mae: 0.15327
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 19
# Testing parameters: hidden_size=3072, dropout_fraction=0.0, learning_rate=0.001
# Эпоха [1/50], train-loss: 0.88107, train-r2: -0.75525, val-loss: 0.42994, val-r2: 0.26647, val-mae: 0.14610
# Эпоха [2/50], train-loss: 0.43373, train-r2: 0.02707, val-loss: 0.41470, val-r2: 0.34660, val-mae: 0.13855
# Эпоха [3/50], train-loss: 0.40788, train-r2: 0.26813, val-loss: 0.42419, val-r2: 0.29455, val-mae: 0.14824
# EarlyStopping counter: 1/5
# Эпоха [4/50], train-loss: 0.38603, train-r2: 0.44336, val-loss: 0.46510, val-r2: 0.00473, val-mae: 0.19116
# EarlyStopping counter: 2/5
# Эпоха [5/50], train-loss: 0.37531, train-r2: 0.47265, val-loss: 0.41835, val-r2: 0.33323, val-mae: 0.13427
# EarlyStopping counter: 3/5
# Эпоха [6/50], train-loss: 0.36509, train-r2: 0.47653, val-loss: 0.42049, val-r2: 0.34423, val-mae: 0.13528
# EarlyStopping counter: 4/5
# Эпоха [7/50], train-loss: 0.35521, train-r2: 0.57606, val-loss: 0.41922, val-r2: 0.34661, val-mae: 0.13115
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 7
# Эпоха [1/50], train-loss: 0.70022, train-r2: -0.94180, val-loss: 0.46904, val-r2: 0.26757, val-mae: 0.16474
# Эпоха [2/50], train-loss: 0.41802, train-r2: 0.12871, val-loss: 0.48275, val-r2: 0.18796, val-mae: 0.16811
# EarlyStopping counter: 1/5
# Эпоха [3/50], train-loss: 0.39352, train-r2: 0.22906, val-loss: 0.46087, val-r2: 0.33394, val-mae: 0.15526
# Эпоха [4/50], train-loss: 0.37458, train-r2: 0.41113, val-loss: 0.45563, val-r2: 0.31444, val-mae: 0.15657
# EarlyStopping counter: 1/5
# Эпоха [5/50], train-loss: 0.36372, train-r2: 0.45060, val-loss: 0.47700, val-r2: 0.31580, val-mae: 0.14477
# EarlyStopping counter: 2/5
# Эпоха [6/50], train-loss: 0.35648, train-r2: 0.52750, val-loss: 0.45564, val-r2: 0.33423, val-mae: 0.15007
# EarlyStopping counter: 3/5
# Эпоха [7/50], train-loss: 0.34417, train-r2: 0.60308, val-loss: 0.47155, val-r2: 0.34461, val-mae: 0.14663
# Эпоха [8/50], train-loss: 0.34378, train-r2: 0.57549, val-loss: 0.45137, val-r2: 0.37091, val-mae: 0.14487
# Эпоха [9/50], train-loss: 0.33319, train-r2: 0.59810, val-loss: 0.44671, val-r2: 0.36805, val-mae: 0.14433
# EarlyStopping counter: 1/5
# Эпоха [10/50], train-loss: 0.32925, train-r2: 0.66181, val-loss: 0.45503, val-r2: 0.36029, val-mae: 0.14450
# EarlyStopping counter: 2/5
# Эпоха [11/50], train-loss: 0.33457, train-r2: 0.59444, val-loss: 0.45181, val-r2: 0.37084, val-mae: 0.14461
# EarlyStopping counter: 3/5
# Эпоха [12/50], train-loss: 0.32524, train-r2: 0.68658, val-loss: 0.44733, val-r2: 0.37949, val-mae: 0.14735
# Эпоха [13/50], train-loss: 0.32663, train-r2: 0.64448, val-loss: 0.44911, val-r2: 0.36754, val-mae: 0.14511
# EarlyStopping counter: 1/5
# Эпоха [14/50], train-loss: 0.32121, train-r2: 0.71324, val-loss: 0.45486, val-r2: 0.36035, val-mae: 0.14279
# EarlyStopping counter: 2/5
# Эпоха [15/50], train-loss: 0.32096, train-r2: 0.55921, val-loss: 0.45008, val-r2: 0.37125, val-mae: 0.14535
# EarlyStopping counter: 3/5
# Эпоха [16/50], train-loss: 0.31506, train-r2: 0.76588, val-loss: 0.45200, val-r2: 0.36350, val-mae: 0.14337
# EarlyStopping counter: 4/5
# Эпоха [17/50], train-loss: 0.31868, train-r2: 0.71196, val-loss: 0.45539, val-r2: 0.36504, val-mae: 0.13654
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 17
# Эпоха [1/50], train-loss: 0.75169, train-r2: -1.02805, val-loss: 0.47317, val-r2: 0.23023, val-mae: 0.16088
# Эпоха [2/50], train-loss: 0.42893, train-r2: -0.02030, val-loss: 0.45966, val-r2: 0.29692, val-mae: 0.14923
# Эпоха [3/50], train-loss: 0.39275, train-r2: 0.34939, val-loss: 0.44319, val-r2: 0.31020, val-mae: 0.15104
# Эпоха [4/50], train-loss: 0.37867, train-r2: 0.32452, val-loss: 0.44636, val-r2: 0.35356, val-mae: 0.14205
# Эпоха [5/50], train-loss: 0.37117, train-r2: 0.44181, val-loss: 0.44308, val-r2: 0.32303, val-mae: 0.15268
# EarlyStopping counter: 1/5
# Эпоха [6/50], train-loss: 0.36624, train-r2: 0.47119, val-loss: 0.45355, val-r2: 0.27858, val-mae: 0.15287
# EarlyStopping counter: 2/5
# Эпоха [7/50], train-loss: 0.35417, train-r2: 0.57466, val-loss: 0.45374, val-r2: 0.32980, val-mae: 0.14096
# EarlyStopping counter: 3/5
# Эпоха [8/50], train-loss: 0.34650, train-r2: 0.60824, val-loss: 0.46080, val-r2: 0.27575, val-mae: 0.14957
# EarlyStopping counter: 4/5
# Эпоха [9/50], train-loss: 0.33900, train-r2: 0.62862, val-loss: 0.45740, val-r2: 0.26637, val-mae: 0.15784
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 9
# Testing parameters: hidden_size=3072, dropout_fraction=0.0, learning_rate=0.0001
# Эпоха [1/50], train-loss: 0.57651, train-r2: -0.74365, val-loss: 0.45665, val-r2: 0.13875, val-mae: 0.16156
# Эпоха [2/50], train-loss: 0.43032, train-r2: 0.13294, val-loss: 0.45052, val-r2: 0.21944, val-mae: 0.14555
# Эпоха [3/50], train-loss: 0.38134, train-r2: 0.19594, val-loss: 0.43143, val-r2: 0.29906, val-mae: 0.13947
# Эпоха [4/50], train-loss: 0.36748, train-r2: 0.46862, val-loss: 0.42744, val-r2: 0.30167, val-mae: 0.14185
# EarlyStopping counter: 1/5
# Эпоха [5/50], train-loss: 0.35400, train-r2: 0.58113, val-loss: 0.43235, val-r2: 0.24128, val-mae: 0.14891
# EarlyStopping counter: 2/5
# Эпоха [6/50], train-loss: 0.35329, train-r2: 0.55614, val-loss: 0.42835, val-r2: 0.29186, val-mae: 0.13970
# EarlyStopping counter: 3/5
# Эпоха [7/50], train-loss: 0.34713, train-r2: 0.58651, val-loss: 0.41845, val-r2: 0.35208, val-mae: 0.12936
# Эпоха [8/50], train-loss: 0.34098, train-r2: 0.63338, val-loss: 0.42322, val-r2: 0.32043, val-mae: 0.13426
# EarlyStopping counter: 1/5
# Эпоха [9/50], train-loss: 0.33935, train-r2: 0.60322, val-loss: 0.41977, val-r2: 0.33262, val-mae: 0.13277
# EarlyStopping counter: 2/5
# Эпоха [10/50], train-loss: 0.33897, train-r2: 0.63596, val-loss: 0.42105, val-r2: 0.34759, val-mae: 0.13204
# EarlyStopping counter: 3/5
# Эпоха [11/50], train-loss: 0.33691, train-r2: 0.63142, val-loss: 0.41811, val-r2: 0.32870, val-mae: 0.13505
# EarlyStopping counter: 4/5
# Эпоха [12/50], train-loss: 0.33128, train-r2: 0.70588, val-loss: 0.41103, val-r2: 0.36777, val-mae: 0.13766
# Эпоха [13/50], train-loss: 0.32782, train-r2: 0.71566, val-loss: 0.41320, val-r2: 0.36097, val-mae: 0.12888
# EarlyStopping counter: 1/5
# Эпоха [14/50], train-loss: 0.32644, train-r2: 0.72914, val-loss: 0.41253, val-r2: 0.36023, val-mae: 0.13163
# EarlyStopping counter: 2/5
# Эпоха [15/50], train-loss: 0.32402, train-r2: 0.76628, val-loss: 0.40545, val-r2: 0.39411, val-mae: 0.12839
# Эпоха [16/50], train-loss: 0.32378, train-r2: 0.73448, val-loss: 0.41382, val-r2: 0.35509, val-mae: 0.13065
# EarlyStopping counter: 1/5
# Эпоха [17/50], train-loss: 0.32353, train-r2: 0.76214, val-loss: 0.40268, val-r2: 0.40096, val-mae: 0.12411
# Эпоха [18/50], train-loss: 0.32280, train-r2: 0.74150, val-loss: 0.40656, val-r2: 0.38278, val-mae: 0.13452
# EarlyStopping counter: 1/5
# Эпоха [19/50], train-loss: 0.32245, train-r2: 0.75064, val-loss: 0.41045, val-r2: 0.37533, val-mae: 0.12934
# EarlyStopping counter: 2/5
# Эпоха [20/50], train-loss: 0.31739, train-r2: 0.79984, val-loss: 0.41396, val-r2: 0.35375, val-mae: 0.13314
# EarlyStopping counter: 3/5
# Эпоха [21/50], train-loss: 0.31748, train-r2: 0.78886, val-loss: 0.40731, val-r2: 0.40033, val-mae: 0.12580
# EarlyStopping counter: 4/5
# Эпоха [22/50], train-loss: 0.32040, train-r2: 0.79278, val-loss: 0.41907, val-r2: 0.34470, val-mae: 0.13163
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 22
# Эпоха [1/50], train-loss: 0.55016, train-r2: -0.88475, val-loss: 0.52387, val-r2: 0.12422, val-mae: 0.17240
# Эпоха [2/50], train-loss: 0.41497, train-r2: -0.01219, val-loss: 0.50339, val-r2: 0.23861, val-mae: 0.15845
# Эпоха [3/50], train-loss: 0.37698, train-r2: 0.40824, val-loss: 0.47008, val-r2: 0.30330, val-mae: 0.15428
# Эпоха [4/50], train-loss: 0.35256, train-r2: 0.49098, val-loss: 0.46320, val-r2: 0.32404, val-mae: 0.14846
# Эпоха [5/50], train-loss: 0.34935, train-r2: 0.47000, val-loss: 0.44864, val-r2: 0.37683, val-mae: 0.14289
# Эпоха [6/50], train-loss: 0.33999, train-r2: 0.54163, val-loss: 0.45784, val-r2: 0.34741, val-mae: 0.14841
# EarlyStopping counter: 1/5
# Эпоха [7/50], train-loss: 0.33430, train-r2: 0.63695, val-loss: 0.45698, val-r2: 0.34219, val-mae: 0.14826
# EarlyStopping counter: 2/5
# Эпоха [8/50], train-loss: 0.33138, train-r2: 0.60236, val-loss: 0.44951, val-r2: 0.36618, val-mae: 0.14724
# EarlyStopping counter: 3/5
# Эпоха [9/50], train-loss: 0.32776, train-r2: 0.62456, val-loss: 0.45100, val-r2: 0.36091, val-mae: 0.14364
# EarlyStopping counter: 4/5
# Эпоха [10/50], train-loss: 0.32465, train-r2: 0.66828, val-loss: 0.45187, val-r2: 0.37349, val-mae: 0.13715
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 10
# Эпоха [1/50], train-loss: 0.57521, train-r2: -0.93849, val-loss: 0.51100, val-r2: 0.13208, val-mae: 0.16706
# Эпоха [2/50], train-loss: 0.42236, train-r2: 0.01762, val-loss: 0.48447, val-r2: 0.20601, val-mae: 0.15613
# Эпоха [3/50], train-loss: 0.37052, train-r2: 0.38048, val-loss: 0.45613, val-r2: 0.27969, val-mae: 0.15028
# Эпоха [4/50], train-loss: 0.36381, train-r2: 0.45265, val-loss: 0.46724, val-r2: 0.25652, val-mae: 0.14798
# EarlyStopping counter: 1/5
# Эпоха [5/50], train-loss: 0.35527, train-r2: 0.50770, val-loss: 0.47780, val-r2: 0.24864, val-mae: 0.14580
# EarlyStopping counter: 2/5
# Эпоха [6/50], train-loss: 0.34803, train-r2: 0.52714, val-loss: 0.46090, val-r2: 0.28546, val-mae: 0.14603
# Эпоха [7/50], train-loss: 0.34542, train-r2: 0.60888, val-loss: 0.44965, val-r2: 0.29601, val-mae: 0.14977
# Эпоха [8/50], train-loss: 0.33859, train-r2: 0.66215, val-loss: 0.46679, val-r2: 0.25785, val-mae: 0.15009
# EarlyStopping counter: 1/5
# Эпоха [9/50], train-loss: 0.33871, train-r2: 0.63830, val-loss: 0.44139, val-r2: 0.34076, val-mae: 0.14317
# Эпоха [10/50], train-loss: 0.33354, train-r2: 0.69432, val-loss: 0.46626, val-r2: 0.28152, val-mae: 0.14663
# EarlyStopping counter: 1/5
# Эпоха [11/50], train-loss: 0.33124, train-r2: 0.68316, val-loss: 0.45337, val-r2: 0.28923, val-mae: 0.14571
# EarlyStopping counter: 2/5
# Эпоха [12/50], train-loss: 0.32655, train-r2: 0.72134, val-loss: 0.44298, val-r2: 0.32165, val-mae: 0.14341
# EarlyStopping counter: 3/5
# Эпоха [13/50], train-loss: 0.32822, train-r2: 0.68122, val-loss: 0.43829, val-r2: 0.34198, val-mae: 0.14152
# EarlyStopping counter: 4/5
# Эпоха [14/50], train-loss: 0.32457, train-r2: 0.70817, val-loss: 0.44550, val-r2: 0.32883, val-mae: 0.14426
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 14
# Testing parameters: hidden_size=3072, dropout_fraction=0.2, learning_rate=0.001
# Эпоха [1/50], train-loss: 0.71345, train-r2: -0.78138, val-loss: 0.43973, val-r2: 0.18541, val-mae: 0.16652
# Эпоха [2/50], train-loss: 0.43744, train-r2: 0.09719, val-loss: 0.44072, val-r2: 0.16669, val-mae: 0.16954
# EarlyStopping counter: 1/5
# Эпоха [3/50], train-loss: 0.41585, train-r2: 0.14992, val-loss: 0.44778, val-r2: 0.15138, val-mae: 0.16201
# EarlyStopping counter: 2/5
# Эпоха [4/50], train-loss: 0.40277, train-r2: 0.14162, val-loss: 0.42361, val-r2: 0.28843, val-mae: 0.14569
# Эпоха [5/50], train-loss: 0.38418, train-r2: 0.40583, val-loss: 0.44170, val-r2: 0.23547, val-mae: 0.14452
# EarlyStopping counter: 1/5
# Эпоха [6/50], train-loss: 0.37838, train-r2: 0.37674, val-loss: 0.42032, val-r2: 0.35178, val-mae: 0.13679
# Эпоха [7/50], train-loss: 0.36988, train-r2: 0.53053, val-loss: 0.42470, val-r2: 0.29064, val-mae: 0.13609
# EarlyStopping counter: 1/5
# Эпоха [8/50], train-loss: 0.36283, train-r2: 0.55344, val-loss: 0.42274, val-r2: 0.26382, val-mae: 0.14554
# EarlyStopping counter: 2/5
# Эпоха [9/50], train-loss: 0.35760, train-r2: 0.55671, val-loss: 0.41810, val-r2: 0.34871, val-mae: 0.13334
# EarlyStopping counter: 3/5
# Эпоха [10/50], train-loss: 0.35419, train-r2: 0.55363, val-loss: 0.42060, val-r2: 0.35319, val-mae: 0.13255
# EarlyStopping counter: 4/5
# Эпоха [11/50], train-loss: 0.34589, train-r2: 0.63091, val-loss: 0.41874, val-r2: 0.32777, val-mae: 0.13356
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 11
# Эпоха [1/50], train-loss: 0.73174, train-r2: -0.92037, val-loss: 0.48867, val-r2: 0.18293, val-mae: 0.16729
# Эпоха [2/50], train-loss: 0.41970, train-r2: 0.09205, val-loss: 0.46139, val-r2: 0.31596, val-mae: 0.15444
# Эпоха [3/50], train-loss: 0.39644, train-r2: 0.22828, val-loss: 0.46167, val-r2: 0.31109, val-mae: 0.15967
# EarlyStopping counter: 1/5
# Эпоха [4/50], train-loss: 0.39027, train-r2: 0.23571, val-loss: 0.47395, val-r2: 0.29545, val-mae: 0.15617
# EarlyStopping counter: 2/5
# Эпоха [5/50], train-loss: 0.38016, train-r2: 0.30784, val-loss: 0.48956, val-r2: 0.23862, val-mae: 0.16635
# EarlyStopping counter: 3/5
# Эпоха [6/50], train-loss: 0.36628, train-r2: 0.39643, val-loss: 0.46181, val-r2: 0.31240, val-mae: 0.15727
# EarlyStopping counter: 4/5
# Эпоха [7/50], train-loss: 0.35744, train-r2: 0.37038, val-loss: 0.45966, val-r2: 0.30525, val-mae: 0.15685
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 7
# Эпоха [1/50], train-loss: 0.72813, train-r2: -1.20736, val-loss: 0.49108, val-r2: 0.14961, val-mae: 0.16714
# Эпоха [2/50], train-loss: 0.43385, train-r2: 0.06168, val-loss: 0.47603, val-r2: 0.19193, val-mae: 0.16705
# Эпоха [3/50], train-loss: 0.40693, train-r2: 0.18828, val-loss: 0.45208, val-r2: 0.26335, val-mae: 0.16414
# Эпоха [4/50], train-loss: 0.39511, train-r2: 0.06306, val-loss: 0.45328, val-r2: 0.27112, val-mae: 0.15706
# Эпоха [5/50], train-loss: 0.38174, train-r2: 0.39049, val-loss: 0.45105, val-r2: 0.33285, val-mae: 0.14494
# Эпоха [6/50], train-loss: 0.36815, train-r2: 0.43719, val-loss: 0.46770, val-r2: 0.24192, val-mae: 0.15553
# EarlyStopping counter: 1/5
# Эпоха [7/50], train-loss: 0.36851, train-r2: 0.42404, val-loss: 0.45522, val-r2: 0.29915, val-mae: 0.14706
# EarlyStopping counter: 2/5
# Эпоха [8/50], train-loss: 0.35366, train-r2: 0.58102, val-loss: 0.45248, val-r2: 0.31363, val-mae: 0.14632
# EarlyStopping counter: 3/5
# Эпоха [9/50], train-loss: 0.35183, train-r2: 0.61519, val-loss: 0.46571, val-r2: 0.29323, val-mae: 0.14849
# EarlyStopping counter: 4/5
# Эпоха [10/50], train-loss: 0.35375, train-r2: 0.56360, val-loss: 0.45026, val-r2: 0.31424, val-mae: 0.14531
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 10
# Testing parameters: hidden_size=3072, dropout_fraction=0.2, learning_rate=0.0001
# Эпоха [1/50], train-loss: 0.55877, train-r2: -0.79463, val-loss: 0.48442, val-r2: 0.00978, val-mae: 0.17803
# Эпоха [2/50], train-loss: 0.44506, train-r2: -0.01346, val-loss: 0.43552, val-r2: 0.21976, val-mae: 0.15390
# Эпоха [3/50], train-loss: 0.40195, train-r2: 0.13789, val-loss: 0.43488, val-r2: 0.21602, val-mae: 0.15506
# EarlyStopping counter: 1/5
# Эпоха [4/50], train-loss: 0.38609, train-r2: 0.29814, val-loss: 0.45724, val-r2: 0.07568, val-mae: 0.17427
# EarlyStopping counter: 2/5
# Эпоха [5/50], train-loss: 0.37590, train-r2: 0.26329, val-loss: 0.43396, val-r2: 0.24151, val-mae: 0.14732
# Эпоха [6/50], train-loss: 0.36967, train-r2: 0.40697, val-loss: 0.43510, val-r2: 0.19408, val-mae: 0.15734
# EarlyStopping counter: 1/5
# Эпоха [7/50], train-loss: 0.36615, train-r2: 0.42910, val-loss: 0.43047, val-r2: 0.25586, val-mae: 0.14997
# Эпоха [8/50], train-loss: 0.35638, train-r2: 0.54484, val-loss: 0.41434, val-r2: 0.33301, val-mae: 0.13619
# Эпоха [9/50], train-loss: 0.35531, train-r2: 0.51781, val-loss: 0.42885, val-r2: 0.23554, val-mae: 0.15266
# EarlyStopping counter: 1/5
# Эпоха [10/50], train-loss: 0.34874, train-r2: 0.61093, val-loss: 0.41710, val-r2: 0.31164, val-mae: 0.14297
# EarlyStopping counter: 2/5
# Эпоха [11/50], train-loss: 0.34909, train-r2: 0.57849, val-loss: 0.41391, val-r2: 0.33022, val-mae: 0.14059
# EarlyStopping counter: 3/5
# Эпоха [12/50], train-loss: 0.34514, train-r2: 0.59000, val-loss: 0.42857, val-r2: 0.24754, val-mae: 0.14908
# EarlyStopping counter: 4/5
# Эпоха [13/50], train-loss: 0.33951, train-r2: 0.66286, val-loss: 0.41056, val-r2: 0.35837, val-mae: 0.13623
# Эпоха [14/50], train-loss: 0.34110, train-r2: 0.66505, val-loss: 0.41718, val-r2: 0.31613, val-mae: 0.14224
# EarlyStopping counter: 1/5
# Эпоха [15/50], train-loss: 0.33964, train-r2: 0.61726, val-loss: 0.41281, val-r2: 0.34309, val-mae: 0.13878
# EarlyStopping counter: 2/5
# Эпоха [16/50], train-loss: 0.33721, train-r2: 0.67789, val-loss: 0.41611, val-r2: 0.34376, val-mae: 0.13705
# EarlyStopping counter: 3/5
# Эпоха [17/50], train-loss: 0.33395, train-r2: 0.71294, val-loss: 0.41226, val-r2: 0.33736, val-mae: 0.14080
# EarlyStopping counter: 4/5
# Эпоха [18/50], train-loss: 0.33131, train-r2: 0.70422, val-loss: 0.41349, val-r2: 0.34381, val-mae: 0.13997
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 18
# Эпоха [1/50], train-loss: 0.54575, train-r2: -0.69713, val-loss: 0.51906, val-r2: 0.12550, val-mae: 0.18033
# Эпоха [2/50], train-loss: 0.42884, train-r2: -0.04733, val-loss: 0.48991, val-r2: 0.16367, val-mae: 0.18203
# Эпоха [3/50], train-loss: 0.39151, train-r2: 0.07365, val-loss: 0.49072, val-r2: 0.17502, val-mae: 0.18174
# Эпоха [4/50], train-loss: 0.37510, train-r2: 0.25046, val-loss: 0.47896, val-r2: 0.22950, val-mae: 0.17156
# Эпоха [5/50], train-loss: 0.36973, train-r2: 0.36217, val-loss: 0.49372, val-r2: 0.19888, val-mae: 0.16879
# EarlyStopping counter: 1/5
# Эпоха [6/50], train-loss: 0.36328, train-r2: 0.44647, val-loss: 0.46985, val-r2: 0.26651, val-mae: 0.16391
# Эпоха [7/50], train-loss: 0.34774, train-r2: 0.53186, val-loss: 0.47506, val-r2: 0.22917, val-mae: 0.17083
# EarlyStopping counter: 1/5
# Эпоха [8/50], train-loss: 0.34915, train-r2: 0.41612, val-loss: 0.47168, val-r2: 0.25606, val-mae: 0.16490
# EarlyStopping counter: 2/5
# Эпоха [9/50], train-loss: 0.34379, train-r2: 0.57495, val-loss: 0.45902, val-r2: 0.34328, val-mae: 0.14907
# Эпоха [10/50], train-loss: 0.34192, train-r2: 0.52006, val-loss: 0.46261, val-r2: 0.31399, val-mae: 0.15369
# EarlyStopping counter: 1/5
# Эпоха [11/50], train-loss: 0.34036, train-r2: 0.54941, val-loss: 0.45288, val-r2: 0.33818, val-mae: 0.16007
# EarlyStopping counter: 2/5
# Эпоха [12/50], train-loss: 0.33942, train-r2: 0.58158, val-loss: 0.45336, val-r2: 0.35440, val-mae: 0.14861
# Эпоха [13/50], train-loss: 0.33529, train-r2: 0.56011, val-loss: 0.45309, val-r2: 0.36038, val-mae: 0.15112
# Эпоха [14/50], train-loss: 0.32999, train-r2: 0.65067, val-loss: 0.44972, val-r2: 0.37095, val-mae: 0.14725
# Эпоха [15/50], train-loss: 0.33026, train-r2: 0.60280, val-loss: 0.45171, val-r2: 0.34087, val-mae: 0.15287
# EarlyStopping counter: 1/5
# Эпоха [16/50], train-loss: 0.32768, train-r2: 0.65705, val-loss: 0.44683, val-r2: 0.37005, val-mae: 0.14948
# EarlyStopping counter: 2/5
# Эпоха [17/50], train-loss: 0.32114, train-r2: 0.68649, val-loss: 0.44090, val-r2: 0.40367, val-mae: 0.14642
# Эпоха [18/50], train-loss: 0.32030, train-r2: 0.65024, val-loss: 0.44823, val-r2: 0.36635, val-mae: 0.14498
# EarlyStopping counter: 1/5
# Эпоха [19/50], train-loss: 0.32173, train-r2: 0.66602, val-loss: 0.44224, val-r2: 0.39238, val-mae: 0.14682
# EarlyStopping counter: 2/5
# Эпоха [20/50], train-loss: 0.32114, train-r2: 0.66866, val-loss: 0.45245, val-r2: 0.37491, val-mae: 0.14483
# EarlyStopping counter: 3/5
# Эпоха [21/50], train-loss: 0.31616, train-r2: 0.69756, val-loss: 0.44746, val-r2: 0.35460, val-mae: 0.15533
# EarlyStopping counter: 4/5
# Эпоха [22/50], train-loss: 0.31796, train-r2: 0.68525, val-loss: 0.44678, val-r2: 0.36858, val-mae: 0.14643
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 22
# Эпоха [1/50], train-loss: 0.54302, train-r2: -0.60988, val-loss: 0.49827, val-r2: 0.08552, val-mae: 0.18361
# Эпоха [2/50], train-loss: 0.43627, train-r2: -0.12379, val-loss: 0.48659, val-r2: 0.21479, val-mae: 0.16425
# Эпоха [3/50], train-loss: 0.40114, train-r2: 0.27727, val-loss: 0.45525, val-r2: 0.27516, val-mae: 0.15899
# Эпоха [4/50], train-loss: 0.37926, train-r2: 0.35204, val-loss: 0.45932, val-r2: 0.26576, val-mae: 0.16181
# EarlyStopping counter: 1/5
# Эпоха [5/50], train-loss: 0.37785, train-r2: 0.41201, val-loss: 0.45489, val-r2: 0.25648, val-mae: 0.16385
# EarlyStopping counter: 2/5
# Эпоха [6/50], train-loss: 0.36171, train-r2: 0.47090, val-loss: 0.46377, val-r2: 0.22322, val-mae: 0.16337
# EarlyStopping counter: 3/5
# Эпоха [7/50], train-loss: 0.35708, train-r2: 0.47932, val-loss: 0.45959, val-r2: 0.24419, val-mae: 0.15822
# EarlyStopping counter: 4/5
# Эпоха [8/50], train-loss: 0.35787, train-r2: 0.52336, val-loss: 0.46047, val-r2: 0.23290, val-mae: 0.16460
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 8
# Эпоха [1/50], train-loss: 0.48015, train-r2: -0.14048, val-loss: 0.39519, val-r2: 0.49370, val-mae: 0.12490
# Эпоха [2/50], train-loss: 0.40000, train-r2: 0.23703, val-loss: 0.35781, val-r2: 0.68921, val-mae: 0.09645
# Эпоха [3/50], train-loss: 0.38065, train-r2: 0.36294, val-loss: 0.34634, val-r2: 0.74509, val-mae: 0.08943
# Эпоха [4/50], train-loss: 0.36195, train-r2: 0.52581, val-loss: 0.33731, val-r2: 0.78027, val-mae: 0.08045
# Эпоха [5/50], train-loss: 0.35297, train-r2: 0.57354, val-loss: 0.32848, val-r2: 0.82558, val-mae: 0.07142
# Эпоха [6/50], train-loss: 0.34690, train-r2: 0.61248, val-loss: 0.32581, val-r2: 0.83821, val-mae: 0.07166
# Эпоха [7/50], train-loss: 0.33863, train-r2: 0.69145, val-loss: 0.32194, val-r2: 0.83681, val-mae: 0.06753
# EarlyStopping counter: 1/5
# Эпоха [8/50], train-loss: 0.33640, train-r2: 0.69012, val-loss: 0.32192, val-r2: 0.84222, val-mae: 0.06667
# EarlyStopping counter: 2/5
# Эпоха [9/50], train-loss: 0.33385, train-r2: 0.68806, val-loss: 0.31825, val-r2: 0.86162, val-mae: 0.06288
# Эпоха [10/50], train-loss: 0.32734, train-r2: 0.73809, val-loss: 0.31246, val-r2: 0.88797, val-mae: 0.05630
# Эпоха [11/50], train-loss: 0.32925, train-r2: 0.73782, val-loss: 0.31295, val-r2: 0.88381, val-mae: 0.05721
# EarlyStopping counter: 1/5
# Эпоха [12/50], train-loss: 0.32316, train-r2: 0.78651, val-loss: 0.31188, val-r2: 0.88597, val-mae: 0.05555
# EarlyStopping counter: 2/5
# Эпоха [13/50], train-loss: 0.32729, train-r2: 0.73938, val-loss: 0.31279, val-r2: 0.88625, val-mae: 0.05584
# EarlyStopping counter: 3/5
# Эпоха [14/50], train-loss: 0.32527, train-r2: 0.75028, val-loss: 0.30735, val-r2: 0.90850, val-mae: 0.05084
# Эпоха [15/50], train-loss: 0.32334, train-r2: 0.76601, val-loss: 0.30622, val-r2: 0.91645, val-mae: 0.04788
# Эпоха [16/50], train-loss: 0.32101, train-r2: 0.77253, val-loss: 0.31208, val-r2: 0.88196, val-mae: 0.05770
# EarlyStopping counter: 1/5
# Эпоха [17/50], train-loss: 0.31968, train-r2: 0.80062, val-loss: 0.31028, val-r2: 0.88729, val-mae: 0.05481
# EarlyStopping counter: 2/5
# Эпоха [18/50], train-loss: 0.32250, train-r2: 0.77066, val-loss: 0.30398, val-r2: 0.92119, val-mae: 0.04617
# EarlyStopping counter: 3/5
# Эпоха [19/50], train-loss: 0.31929, train-r2: 0.80998, val-loss: 0.30908, val-r2: 0.90282, val-mae: 0.05275
# EarlyStopping counter: 4/5
# Эпоха [20/50], train-loss: 0.31741, train-r2: 0.79670, val-loss: 0.30661, val-r2: 0.90725, val-mae: 0.05102
# EarlyStopping counter: 5/5
# Restoring best model weights
# Early stopping triggered at epoch 20

# %% [markdown]
# Выведем результаты лучших моделей на кроссвалидации для обеих архетиктур.

# %%
print('Параметры лучшей линейной регрессии на кроссвалидации:', best_lr_params)
print('R2 (после сигмоиды) лучшей линейной регрессии на кроссвалидации:', best_lr_metric)
print('MAE (после сигмоиды) лучшей линейной регрессии на кроссвалидации:', best_lr_metric_2)
print('Параметры лучшей нейронной сети на кроссвалидации:', best_nn_params)
print('R2 лучшей нейронной сети на кроссвалидации:', best_nn_metric)
print('MAE лучшей нейронной сети на кроссвалидации:', best_nn_metric_2)
# Out:
# Параметры лучшей линейной регрессии на кроссвалидации: {'learning_rate': 0.001}
# R2 (после сигмоиды) лучшей линейной регрессии на кроссвалидации: -1.6458907922108967
# MAE (после сигмоиды) лучшей линейной регрессии на кроссвалидации: 0.37758706013361615
# Параметры лучшей нейронной сети на кроссвалидации: {'dropout_fraction': 0.0, 'hidden_size': 512, 'learning_rate': 0.001}
# R2 лучшей нейронной сети на кроссвалидации: 0.3964913288752238
# MAE лучшей нейронной сети на кроссвалидации: 0.1350934555133184

# %% [markdown]
# По результатам кроссвалидации лучшие значения метрик показала модель нейронной сети с парметрами {{best_nn_params}}, поэтому именно ее мы будем использовать в дальнейшем.

# %% [markdown]
# ## 8. Тестирование модели

# %% [markdown]
# Подготовим тестовые данные.

# %%
# Удалим юридически вредный контент
test_df, removed_data = remove_restricted_data(test_queries_df)
# Создадим эмбеддинги изображений
test_df = embed_imgs(img_embedder, test_df, img_path=TEST_IMG_DIR)
test_df = test_df.reset_index(drop=True)

test_df.info()
test_df.head()
# Out:
# Количество строк с неприемлемым контентом: 169
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   query_id    331 non-null    object
#  1   query_text  331 non-null    object
#  2   image       331 non-null    object
#  3   img_embeds  331 non-null    object
# dtypes: object(4)
# memory usage: 10.5+ KB
#                       query_id  \
# 0   123997871_6a9ca987b1.jpg#1
# 1   123997871_6a9ca987b1.jpg#3
# 2   123997871_6a9ca987b1.jpg#4
# 3  1319634306_816f21677f.jpg#0
# 4  1319634306_816f21677f.jpg#1
#
#                                           query_text  \
# 0  Several female lacrosse players are going afte...
# 1  The woman lacrosse player in blue is about to ...
# 2                              Women play lacrosse .
# 3        A brown dog is sitting in some long grass .
# 4             A brown dog sits still on a hillside .
#
#                        image  \
# 0   123997871_6a9ca987b1.jpg
# 1   123997871_6a9ca987b1.jpg
# 2   123997871_6a9ca987b1.jpg
# 3  1319634306_816f21677f.jpg
# 4  1319634306_816f21677f.jpg
#
#                                           img_embeds
# 0  [tensor(0.1887), tensor(0.0061), tensor(0.1460...
# 1  [tensor(0.1887), tensor(0.0061), tensor(0.1460...
# 2  [tensor(0.1887), tensor(0.0061), tensor(0.1460...
# 3  [tensor(0.0334), tensor(0.), tensor(0.), tenso...
# 4  [tensor(0.0334), tensor(0.), tensor(0.), tenso...

# %% [markdown]
# Напишим функцию, которая принимает на вход текстовое описание, делает его векторизацию и возвращает картинку с максимальным значением метрики. Если запрос ведёт на юридически вредный контент, функция выведет дисклеймер.

# %%
def test_model(queries_df, model, text_embedder, test_data, drop_last=False, img_path=TEST_IMG_DIR):
    """
    Args:
        queries_df (pd.DataFrame): Выборка из тестового датафрейма, содержащая описания для проверки
        model (nn.Module): Модель для тестирования
        text_embedder: Модель текстового эмбеддинга полученная ранее
        test_data (pd.DataFrame): Датафрейм с тестовыми данными
        drop_last (bool): Нужно ли отбрасывать неполный последний батч
        img_path (str): Путь к папке с тестовыми изображениями
    """
    df = test_data.copy()
    # Цикл перебора описаний
    for query in queries_df.itertuples():

        query_text = query.query_text
        # Проверка на юридически вредный контент
        _, removed_data = remove_restricted_data(pd.DataFrame({'query_text': [query_text]}),
                                                verbose=False)
        if len(removed_data) > 0:
            print(f'----------------------------------------------'
                  f'---------------------------------------------')
            print(f'Query: "{query_text}" \n This image is unavailable in your country '
                  f'in compliance with local laws')
            print(f'----------------------------------------------'
                  f'---------------------------------------------')
            continue

        # Создание эмбеддинга запроса
        query_embed = embed_texts(text_embedder,
                                  pd.DataFrame({'query_text': [query_text]}))['text_embeds'][0]
        # Помещаем эмбеддинг запроса в колонку датафрейма тестовых данных
        # для прогона через модель вместе с эмбеддингами всех тестовых изображений
        df['text_embeds'] = [query_embed for i in range(len(df))]


        # Создание dataloader с тестовыми данными + эмбеддинг запроса
        test_loader, _ = load_data(df, df.index, val_indices=None, train=False)

        # Предсказание соответствия запроса для всех тестовых изображений
        predicted = []
        model.eval()
        with torch.no_grad():
            for _data in test_loader:
                outputs = model(_data.to(device)).cpu()
                predicted.append(outputs)
                batch = _data
            predicted = torch.cat(predicted, dim=0)
            # Находим максимальную предсказанную оценку и ее индекс
            max_value, max_index = torch.max(predicted, dim=0)
        # Выводим запрос и изображение с максимальной предсказанной оценкой
        print('--------------------------------------------------')
        fig = plt.figure(figsize=(7, 3))
        image_predicted = Image.open(PATH + img_path + df.loc[int(max_index), 'image'])
        plt.imshow(image_predicted)
        plt.title(f'\nQuery: {query_text}')
        plt.ylabel(f"Оценка: {float(max_value):.4f}")
        plt.xlabel(f"{df['image'].iloc[int(max_index)]}")
        plt.xticks([])
        plt.yticks([])
        plt.show()

# %% [markdown]
# Выберем случайные 10 запросов из тестовых данных и для каждого запроса выведите наиболее релевантное изображение.

# %%
test_queries = test_queries_df.sample(n=10, random_state=RANDOM_STATE)
test_queries
# Out:
#                         query_id  \
# 90   2399219552_bbba0a9a59.jpg#0
# 254  3163198309_bbfe504f0a.jpg#4
# 283  3262849619_0bc4f88ef9.jpg#3
# 445   572618443_647483ca82.jpg#0
# 461   661749711_6f408dad62.jpg#1
# 15   1319634306_816f21677f.jpg#0
# 316  3396275223_ee080df8b5.jpg#1
# 489   973827791_467d83986e.jpg#4
# 159   269650644_059a84ece5.jpg#4
# 153  2687672606_275169c35d.jpg#3
#
#                                             query_text  \
# 90                            A boy plays basketball .
# 254  There are several people watching a person in ...
# 283  A brown and white dog walks in the snow with a...
# 445    A man and two boys standing in spraying water .
# 461  a small shaggy dog plays with a red ball on th...
# 15         A brown dog is sitting in some long grass .
# 316       A group of people perform together onstage .
# 489  I child slides into a wading pool full of wate...
# 159         People using an outdoor ice skating rink .
# 153  The lady in the multi-colored shirt has a neck...
#
#                          image
# 90   2399219552_bbba0a9a59.jpg
# 254  3163198309_bbfe504f0a.jpg
# 283  3262849619_0bc4f88ef9.jpg
# 445   572618443_647483ca82.jpg
# 461   661749711_6f408dad62.jpg
# 15   1319634306_816f21677f.jpg
# 316  3396275223_ee080df8b5.jpg
# 489   973827791_467d83986e.jpg
# 159   269650644_059a84ece5.jpg
# 153  2687672606_275169c35d.jpg

# %%
test_model(test_queries, best_nn_model, text_embedder, test_df)
# Out:
# -------------------------------------------------------------------------------------------
# Query: "A boy plays basketball ."
#  This image is unavailable in your country in compliance with local laws
# -------------------------------------------------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# -------------------------------------------------------------------------------------------
# Query: "A man and two boys standing in spraying water ."
#  This image is unavailable in your country in compliance with local laws
# -------------------------------------------------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# -------------------------------------------------------------------------------------------
# Query: "I child slides into a wading pool full of water while an adult tosses a bucket of water on them ."
#  This image is unavailable in your country in compliance with local laws
# -------------------------------------------------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------

# %% [markdown]
# Визуальная оценка результатов предсказания модели на тестовой выборке может считаться удовлетворительной. В более чем половине случаев модель предсказала подходящее изображение, в других случаях изображения подходят только чатично (содержат нужные объекты или элементы контекста).

# %% [markdown]
# ## Вывод

# %% [markdown]
# Несмотря на крайне ограниченные вычислительные ресурсы и небольшой размер тренировочного датасета, нам удалось построить модель, способную делать полностью или частично верные предсказания. На данном этапе модель предсказывает около 40% вариабельности в данных. Если использовать больше тренировочных данных, модель можно значительно улучшить. Несомненно, проект по созданию сервиса поиска фотографий по текстовому описанию практически осуществим.
